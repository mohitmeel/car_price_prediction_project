# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url='https://www.cars24.com/'
driver.get(url)

# %%
manual=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div[2]/button')
manual
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="4e9af7ba-1092-4e74-bca3-ddf1e6e0d17f")>

# %%
manual.click()

# %%
newdelhi=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[1]')
newdelhi
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="aaf08e86-ed7c-4982-8cec-7ae4d6ab0491")>

# %%
newdelhi.click()

# %%
viewallcars=driver.find_element_by_xpath('/html/body/div[1]/div[4]/section/div/div/div[2]')
viewallcars
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="575c9937-4e7d-46c7-b0f8-8e47fbd0c2df")>

# %%
viewallcars.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="46194399-cdc8-481e-841a-377f2793d760")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="e9220591-b2ad-41b9-9a93-62654a300ef7")>]

# %%
carnames=[]
for i in carname:
    carnames.append(i.text.split()[1:])
carnames
# Out:
# [['Hyundai', 'Verna'],
#  ['KIA', 'SELTOS'],
#  ['KIA', 'SELTOS'],
#  ['Maruti', 'Baleno'],
#  ['Maruti', 'Alto', '800'],
#  ['Skoda', 'Rapid'],
#  ['Jaguar', 'XF'],
#  ['Hyundai', 'i10'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Maruti', 'Swift'],
#  ['Volkswagen', 'Polo'],
#  ['Jeep', 'Compass'],
#  ['Hyundai', 'VENUE'],
#  ['MG', 'HECTOR', 'PLUS'],
#  ['Renault', 'Kwid'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Nissan', 'Micra'],
#  ['Honda', 'City'],
#  ['Hyundai', 'i10'],
#  ['Renault', 'Kiger'],
#  ['Maruti', 'Baleno'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Maruti', 'Alto', 'K10'],
#  ['Maruti', 'Ciaz'],
#  ['Hyundai', 'VENUE'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Toyota', 'Fortuner'],
#  ['Hyundai', 'i10'],
#  ['Hyundai', 'i20'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Honda', 'City'],
#  ['Honda', 'City'],
#  ['Mercedes', 'Benz', 'E', 'Class'],
#  ['Honda', 'City'],
#  ['Toyota', 'URBAN', 'CRUISER'],
#  ['Renault', 'Kwid'],
#  ['Hyundai', 'VENUE'],
# ...

# %%
len(carnames)
# Out:
# 663

# %%
year=[]
for i in carname:
    year.append(i.text.split()[0])
year
# Out:
# ['2019',
#  '2020',
#  '2020',
#  '2018',
#  '2013',
#  '2020',
#  '2013',
#  '2009',
#  '2014',
#  '2019',
#  '2015',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2019',
#  '2014',
#  '2016',
#  '2014',
#  '2021',
#  '2018',
#  '2019',
#  '2011',
#  '2021',
#  '2021',
#  '2020',
#  '2010',
#  '2015',
#  '2011',
#  '2010',
#  '2020',
#  '2020',
#  '2010',
#  '2013',
#  '2014',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2011',
#  '2010',
#  '2021',
#  '2021',
#  '2013',
#  '2015',
#  '2021',
#  '2019',
#  '2017',
#  '2017',
#  '2016',
#  '2019',
#  '2021',
#  '2020',
#  '2014',
#  '2018',
#  '2021',
#  '2017',
#  '2014',
#  '2019',
#  '2019',
#  '2011',
#  '2017',
#  '2021',
#  '2020',
#  '2018',
#  '2017',
#  '2018',
#  '2018',
#  '2015',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2017',
#  '2018',
#  '2018',
#  '2017',
#  '2015',
#  '2018',
#  '2019',
#  '2019',
#  '2016',
#  '2020',
#  '2016',
#  '2016',
#  '2020',
#  '2019',
#  '2018',
#  '2014',
#  '2014',
# ...

# %%
model=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="4d41daa7-1ce0-4093-87ee-f1dc8bb8f0a0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="86033fff-a76e-4012-85ea-ef0f9236e486")>]

# %%
models=[]
for i in model:
    models.append(i.text.replace('Automatic','').replace('Manual',''))
models
# Out:
# ['1.6 SX VTVT (O) ',
#  'HTK PLUS 1.5 PETROL ',
#  'HTX AT PETROL ',
#  'SIGMA 1.2 K12 ',
#  'LXI ',
#  'ACTIVE 1.0 TSI ',
#  '2.2 DIESEL ',
#  'ERA 1.1 IRDE ',
#  'LXI ',
#  'VXI ',
#  'COMFORTLINE 1.2L PETROL ',
#  '2.0 LIMITED ',
#  'S MT 1.2 KAPPA ',
#  'SHARP HYBRID PETROL ',
#  'RXL ',
#  '1.2 MAGNA PLUS VTVT ',
#  'XE DIESEL ',
#  'SV MT PETROL ',
#  'MAGNA 1.1 IRDE2 ',
#  'RXT 1.0 AMT ',
#  'DELTA 1.2 K12 ',
#  'MAGNA 1.2 VTVT ',
#  'VXI ',
#  'ALPHA 1.5 MT VTVT SHVS ',
#  '1.5 SX CRDI MT ',
#  'RXL ',
#  'LXI ',
#  '3.0 AT 4X2 ',
#  'SPORTZ 1.2 KAPPA2 ',
#  'MAGNA O 1.2 ',
#  'MAGNA 1.2 VTVT ',
#  'VX MT PETROL ',
#  'S MT PETROL ',
#  'E 250 CDI AVANTGARDE ',
#  'VX MT PETROL ',
#  'MID MT',
#  'RXT Opt ',
#  '1.0L Turbo GDI SX MT ',
#  '1.0 CLIMBER OPT AMT ',
#  'VXI ',
#  'MAGNA O 1.2 ',
#  'VXI ',
#  '1.0 RXT Opt ',
#  'ERA 1.4 CRDI ',
#  '2.0 2WD AT ',
#  'ALPHA 1.5 MT VTVT SHVS ',
#  'ZXI SMART HYBRID ',
#  'SPORTZ 1.2 ',
#  'SPORTZ (O) 1.2 AT VTVT ',
# ...

# %%
transmission=[]
for i in model:
    transmission.append(i.text.split()[-1])
transmission
# Out:
# ['Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'MT',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'MT',
#  'Automatic',
# ...

# %%
detail=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="9adb1520-eef7-4ece-8b77-c25fc4deb9a6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="d7f73761-946b-47c9-9349-030de9d3e790")>]

# %%
details=[]
for i in detail:
    details.append(i.text.replace('\n',' '))
details
# Out:
# ['80,631 km 1st Owner Petrol',
#  '12,981 km 2nd Owner Petrol',
#  '21,784 km 2nd Owner Petrol',
#  '20,330 km 1st Owner Petrol',
#  '12,849 km 2nd Owner Petrol',
#  '11,399 km 1st Owner Petrol',
#  '28,289 km 2nd Owner Diesel',
#  '44,319 km 1st Owner Petrol',
#  '26,866 km 1st Owner Petrol',
#  '32,251 km 1st Owner Petrol',
#  '51,495 km 1st Owner Petrol',
#  '46,400 km 1st Owner Diesel',
#  '21,490 km 1st Owner Petrol',
#  '2,775 km 1st Owner Petrol',
#  '22,505 km 2nd Owner Petrol',
#  '22,638 km 2nd Owner Petrol',
#  '63,433 km 1st Owner Diesel',
#  '45,246 km 1st Owner Petrol',
#  '12,511 km 1st Owner Petrol',
#  '6,344 km 1st Owner Petrol',
#  '23,315 km 3rd Owner Petrol',
#  '16,327 km 1st Owner Petrol',
#  '37,580 km 1st Owner Petrol',
#  '9,370 km 1st Owner Petrol',
#  '2,213 km 1st Owner Diesel',
#  '19,767 km 1st Owner Petrol',
#  '48,915 km 2nd Owner Petrol',
#  '90,086 km 2nd Owner Diesel',
#  '66,782 km 2nd Owner Petrol',
#  '42,422 km 2nd Owner Petrol',
# ...

# %%
driven=[]
for i in detail:
    driven.append(i.text.split()[0].replace(',',''))
driven
# Out:
# ['80631',
#  '12981',
#  '21784',
#  '20330',
#  '12849',
#  '11399',
#  '28289',
#  '44319',
#  '26866',
#  '32251',
#  '51495',
#  '46400',
#  '21490',
#  '2775',
#  '22505',
#  '22638',
#  '63433',
#  '45246',
#  '12511',
#  '6344',
#  '23315',
#  '16327',
#  '37580',
#  '9370',
#  '2213',
#  '19767',
#  '48915',
#  '90086',
#  '66782',
#  '42422',
#  '13223',
#  '7212',
#  '34566',
#  '42881',
#  '54517',
#  '11828',
#  '2406',
#  '29645',
#  '7760',
#  '26475',
#  '60774',
#  '5287',
#  '6962',
#  '29974',
#  '73937',
#  '4536',
#  '61780',
#  '30697',
#  '12855',
#  '45277',
#  '11358',
#  '6568',
#  '18191',
#  '82295',
#  '23733',
#  '3120',
#  '78203',
#  '32525',
#  '12267',
#  '17858',
#  '23874',
#  '62443',
#  '6910',
#  '31910',
#  '27693',
#  '76959',
#  '13278',
#  '19738',
#  '25238',
#  '22955',
#  '4210',
#  '12225',
#  '7661',
#  '49358',
#  '71745',
#  '45930',
#  '30375',
#  '51358',
#  '31760',
#  '26035',
#  '37503',
#  '34900',
#  '35669',
#  '19360',
# ...

# %%
owner=[]
for i in detail:
    owner.append(i.text.split()[2])
owner
# Out:
# ['1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '2nd',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
# ...

# %%
fueltype=[]
for i in detail:
    fueltype.append(i.text.split()[4])
fueltype
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
# ...

# %%
detail1=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="24ce3a45-3787-4b54-9c4c-f21aef5fbf55")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="3d05d2c2-8b64-4709-b8c2-f5bca3311ac2")>]

# %%
details1=[]
for i in detail1:
    details1.append(i.text.replace('/month\n',' '))
details1
# Out:
# ['₹21,837 ₹9,81,699',
#  '₹25,699 ₹11,55,299',
#  '₹31,810 ₹14,29,999',
#  '₹11,674 ₹5,24,799',
#  '₹5,695 ₹2,55,999',
#  '₹17,433 ₹7,83,699',
#  '₹36,612 ₹16,45,899',
#  '₹4,542 ₹2,04,199',
#  '₹7,832 ₹3,52,099',
#  '₹12,466 ₹5,60,399',
#  '₹9,790 ₹4,40,099',
#  '₹44,934 ₹20,19,999',
#  '₹18,272 ₹8,21,399',
#  '₹40,883 ₹18,37,899',
#  '₹7,174 ₹3,22,499',
#  '₹13,745 ₹6,17,899',
#  '₹6,124 ₹2,75,299',
#  '₹14,781 ₹6,64,499',
#  '₹7,574 ₹3,40,499',
#  '₹18,278 ₹8,21,699',
#  '₹11,976 ₹5,38,399',
#  '₹11,371 ₹5,11,199',
#  '₹5,339 ₹2,39,999',
#  '₹26,996 ₹12,13,599',
#  '₹26,994 ₹12,13,499',
#  '₹7,748 ₹3,48,299',
#  '₹5,430 ₹2,44,099',
#  '₹35,097 ₹15,77,799',
#  '₹6,420 ₹2,88,599',
#  '₹6,015 ₹2,70,399',
#  '₹13,175 ₹5,92,299',
#  '₹29,156 ₹13,10,699',
#  '₹9,429 ₹4,23,899',
#  '₹32,379 ₹14,55,599',
#  '₹14,448 ₹6,49,499',
#  '₹20,596 ₹9,25,899',
#  '₹8,388 ₹3,77,099',
#  '₹22,033 ₹9,90,499',
#  '₹12,379 ₹5,56,499',
#  '₹5,239 ₹2,35,499',
#  '₹6,651 ₹2,98,999',
# ...

# %%
downpayment=[]
for i in detail1:
    downpayment.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment
# Out:
# ['21837',
#  '25699',
#  '31810',
#  '11674',
#  '5695',
#  '17433',
#  '36612',
#  '4542',
#  '7832',
#  '12466',
#  '9790',
#  '44934',
#  '18272',
#  '40883',
#  '7174',
#  '13745',
#  '6124',
#  '14781',
#  '7574',
#  '18278',
#  '11976',
#  '11371',
#  '5339',
#  '26996',
#  '26994',
#  '7748',
#  '5430',
#  '35097',
#  '6420',
#  '6015',
#  '13175',
#  '29156',
#  '9429',
#  '32379',
#  '14448',
#  '20596',
#  '8388',
#  '22033',
#  '12379',
#  '5239',
#  '6651',
#  '20247',
#  '11127',
#  '6813',
#  '28226',
#  '26349',
#  '19840',
#  '11629',
#  '13852',
#  '9543',
#  '9765',
#  '15807',
#  '24565',
#  '21450',
#  '13627',
#  '40096',
#  '19041',
#  '7574',
#  '39466',
#  '10397',
#  '6989',
#  '21630',
#  '23099',
#  '18296',
#  '12165',
#  '27572',
#  '19386',
#  '7892',
#  '9474',
#  '7928',
#  '8940',
#  '10866',
#  '21397',
#  '22794',
#  '28273',
#  '11887',
#  '8455',
#  '7105',
#  '20047',
#  '14935',
#  '31327',
#  '9327',
#  '12426',
#  '10853',
#  '15024',
# ...

# %%
price=[]
for i in detail1:
    price.append(i.text.split()[-1].replace('/month','').replace('₹','').replace(',',''))
price
# Out:
# ['981699',
#  '1155299',
#  '1429999',
#  '524799',
#  '255999',
#  '783699',
#  '1645899',
#  '204199',
#  '352099',
#  '560399',
#  '440099',
#  '2019999',
#  '821399',
#  '1837899',
#  '322499',
#  '617899',
#  '275299',
#  '664499',
#  '340499',
#  '821699',
#  '538399',
#  '511199',
#  '239999',
#  '1213599',
#  '1213499',
#  '348299',
#  '244099',
#  '1577799',
#  '288599',
#  '270399',
#  '592299',
#  '1310699',
#  '423899',
#  '1455599',
#  '649499',
#  '925899',
#  '377099',
#  '990499',
#  '556499',
#  '235499',
#  '298999',
#  '910199',
#  '500199',
#  '306299',
#  '1268899',
#  '1184499',
#  '891899',
#  '522799',
#  '622699',
#  '428999',
#  '438999',
#  '710599',
#  '1104299',
#  '964299',
#  '612599',
#  '1802499',
#  '855999',
#  '340499',
#  '1774199',
#  '467399',
#  '314199',
#  '972399',
#  '1038399',
#  '822499',
#  '546899',
#  '1239499',
#  '871499',
#  '354799',
#  '425899',
#  '356399',
#  '401899',
#  '488499',
#  '961899',
#  '1024699',
#  '1270999',
# ...

# %%
locationchange=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange.click()

# %%
mumbai=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[4]')
mumbai
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="741a9b26-2f09-478f-b799-a5e050a6d828")>

# %%
mumbai.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname1=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="34ccefed-ef0b-4541-bd6d-aa7d5fbabfc7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="9bd00cb1-be01-4bae-9f4a-f2833d026d74")>]

# %%
carnames1=[]
for i in carname1:
    carnames1.append(i.text.split()[1:])
carnames1
# Out:
# [['Maruti', 'Alto', '800'],
#  ['Renault', 'TRIBER'],
#  ['Maruti', 'Celerio'],
#  ['Hyundai', 'i20'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Hyundai', 'i20'],
#  ['Maruti', 'Swift'],
#  ['Renault', 'TRIBER'],
#  ['Maruti', 'New', 'Wagon-R'],
#  ['Maruti', 'Celerio'],
#  ['Maruti', 'Swift', 'Dzire'],
#  ['Hyundai', 'AURA'],
#  ['Mahindra', 'XUV500'],
#  ['Honda', 'Amaze'],
#  ['Maruti', 'Ritz'],
#  ['KIA', 'SONET'],
#  ['Maruti', 'Swift'],
#  ['Renault', 'Kwid'],
#  ['Tata', 'Tiago'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Alto', '800'],
#  ['Maruti', 'Swift', 'Dzire'],
#  ['MG', 'HECTOR'],
#  ['Tata', 'NEXON'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Maruti', 'Swift', 'Dzire'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'S', 'PRESSO'],
#  ['Toyota', 'Corolla', 'Altis'],
#  ['Volkswagen', 'Vento'],
#  ['Maruti', 'New', 'Wagon-R'],
#  ['Hyundai', 'Eon'],
#  ['Tata', 'Harrier'],
#  ['Volkswagen', 'Polo'],
#  ['KIA', 'SELTOS'],
#  ['Honda', 'Civic'],
#  ['Hyundai', 'Xcent'],
# ...

# %%
len(carnames1)
# Out:
# 644

# %%
year1=[]
for i in carname1:
    year1.append(i.text.split()[0])
year1
# Out:
# ['2015',
#  '2020',
#  '2015',
#  '2013',
#  '2014',
#  '2012',
#  '2018',
#  '2019',
#  '2020',
#  '2016',
#  '2012',
#  '2020',
#  '2019',
#  '2020',
#  '2014',
#  '2020',
#  '2017',
#  '2021',
#  '2017',
#  '2012',
#  '2016',
#  '2016',
#  '2019',
#  '2020',
#  '2015',
#  '2012',
#  '2015',
#  '2020',
#  '2014',
#  '2014',
#  '2019',
#  '2014',
#  '2019',
#  '2015',
#  '2020',
#  '2019',
#  '2014',
#  '2013',
#  '2016',
#  '2018',
#  '2017',
#  '2018',
#  '2017',
#  '2018',
#  '2020',
#  '2019',
#  '2015',
#  '2017',
#  '2016',
#  '2017',
#  '2017',
#  '2018',
#  '2016',
#  '2019',
#  '2019',
#  '2017',
#  '2019',
#  '2017',
#  '2016',
#  '2017',
#  '2019',
#  '2014',
#  '2018',
#  '2019',
#  '2016',
#  '2017',
#  '2016',
#  '2016',
#  '2018',
#  '2016',
#  '2019',
#  '2016',
#  '2015',
#  '2016',
#  '2016',
#  '2015',
#  '2018',
#  '2019',
#  '2015',
#  '2014',
#  '2014',
#  '2018',
#  '2016',
#  '2020',
#  '2016',
#  '2018',
#  '2016',
#  '2018',
#  '2013',
#  '2020',
# ...

# %%
model1=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="81b6e87f-16a8-4bdc-a70f-a1029290dc9d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="421584b9-0c65-4ef8-b18e-34e205d250d8")>]

# %%
models1=[]
for i in model1:
    models1.append(i.text.replace('Automatic','').replace('Manual',''))
models1
# Out:
# ['LXI ',
#  'RXZ AT ',
#  'LXI ',
#  'MAGNA O 1.2 ',
#  'LXI ',
#  'SPORTZ 1.2 VTVT ',
#  'VDI AMT ',
#  '1.0 RXZ ',
#  'ZXI 1.2L AGS ',
#  'VXI AMT ',
#  'VDI BS IV ',
#  'E MT 1.2 KAPPA ',
#  'W11 (O) AT ',
#  '1.2 EMT I VTEC ',
#  'VXI ',
#  'GTX PLUS 1.5 DCT AT',
#  'VXI ',
#  '1.0 RXT Opt AT ',
#  'XZA 1.2 REVOTRON ',
#  'VDI ',
#  'VXI ',
#  'ZDI ',
#  'SHARP 2.0 DIESEL ',
#  'XZ+ OPT PETROL ',
#  'ASTA 1.2 ',
#  'VDI BS IV ',
#  'VXI ',
#  'VXI PLUS AGS ',
#  'J S ',
#  'HIGHLINE PETROL ',
#  'VXI (O) 1.2L ',
#  'SPORTZ ',
#  'XZ 2.0L Kryotec ',
#  'GT TSI 1.2 PETROL AT ',
#  'HTK PLUS 1.5 PETROL ',
#  'VX DIESEL ',
#  'SX 1.2 OPT ',
#  'ASTA 1.2 ',
#  'MAGNA 1.2 ',
#  '2.8 ZX AT 7 STR ',
#  'ZETA 1.4 VVT AMT ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'ZX CVT ',
#  'V ',
#  'VXI PLUS AGS ',
#  'ZXI 1.2 ',
#  'MAGNA 1.2 ',
#  'SPORTZ 1.2 ',
#  'VX 1.2 ',
#  '1.5 TITANIUM TI VCT AT ',
#  'Magna Executive 1.2 ',
#  'MAGNA PLUS ',
#  'VXI ',
#  'W8(O) ',
#  'RXT 1.0 EASY-R AT OPTION ',
# ...

# %%
transmission1=[]
for i in model1:
    transmission1.append(i.text.split()[-1])
transmission1
# Out:
# ['Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'AT',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
# ...

# %%
detail1=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="9ef9b0bf-2a4f-4450-9569-e144ab2412ab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="8d2abb2b-1ae7-465c-98fb-6200126c342d")>]

# %%
details1=[]
for i in detail1:
    details1.append(i.text.replace('\n',' '))
details1
# Out:
# ['6,381 km 1st Owner Petrol',
#  '17,396 km 2nd Owner Petrol',
#  '22,939 km 1st Owner Petrol',
#  '34,587 km 1st Owner Petrol',
#  '13,712 km 1st Owner Petrol',
#  '38,910 km 1st Owner Petrol',
#  '53,119 km 2nd Owner Diesel',
#  '7,440 km 1st Owner Petrol',
#  '11,907 km 1st Owner Petrol',
#  '9,836 km 2nd Owner Petrol',
#  '1,34,186 km 1st Owner Diesel',
#  '12,810 km 1st Owner Petrol',
#  '29,100 km 2nd Owner Diesel',
#  '11,596 km 1st Owner Petrol',
#  '58,849 km 1st Owner Petrol',
#  '10,769 km 1st Owner Diesel',
#  '33,801 km 1st Owner Petrol',
#  '810 km 1st Owner Petrol',
#  '3,678 km 2nd Owner Petrol',
#  '69,976 km 2nd Owner Diesel',
#  '32,750 km 1st Owner Petrol',
#  '47,547 km 1st Owner Diesel',
#  '29,347 km 1st Owner Diesel',
#  '5,327 km 1st Owner Petrol',
#  '32,964 km 2nd Owner Petrol',
#  '94 km 2nd Owner Diesel',
#  '24,045 km 1st Owner Petrol',
#  '8,355 km 1st Owner Petrol',
#  '53,337 km 1st Owner Petrol',
#  '39,841 km 1st Owner Petrol',
# ...

# %%
driven1=[]
for i in detail1:
    driven1.append(i.text.split()[0].replace(',',''))
driven1
# Out:
# ['6381',
#  '17396',
#  '22939',
#  '34587',
#  '13712',
#  '38910',
#  '53119',
#  '7440',
#  '11907',
#  '9836',
#  '134186',
#  '12810',
#  '29100',
#  '11596',
#  '58849',
#  '10769',
#  '33801',
#  '810',
#  '3678',
#  '69976',
#  '32750',
#  '47547',
#  '29347',
#  '5327',
#  '32964',
#  '94',
#  '24045',
#  '8355',
#  '53337',
#  '39841',
#  '35273',
#  '16583',
#  '49744',
#  '94384',
#  '28634',
#  '80920',
#  '61977',
#  '41342',
#  '25895',
#  '37590',
#  '30492',
#  '16868',
#  '19400',
#  '19949',
#  '5746',
#  '30741',
#  '52222',
#  '26508',
#  '34633',
#  '471',
#  '24947',
#  '25031',
#  '18537',
#  '39391',
#  '3615',
#  '48562',
#  '9076',
#  '53314',
#  '15692',
#  '30224',
#  '31248',
#  '91203',
#  '27167',
#  '13513',
#  '32503',
#  '41211',
#  '24678',
#  '130064',
#  '20036',
#  '21815',
#  '27546',
#  '32071',
#  '57339',
#  '85211',
#  '81316',
#  '16566',
#  '42012',
#  '12408',
#  '79569',
#  '43624',
#  '38225',
#  '5862',
#  '59839',
#  '25706',
# ...

# %%
owner1=[]
for i in detail1:
    owner1.append(i.text.split()[2])
owner1
# Out:
# ['1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
# ...

# %%
fueltype1=[]
for i in detail1:
    fueltype1.append(i.text.split()[4])
fueltype1
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
# ...

# %%
detail11=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail11[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="3805e4a4-b6b2-4592-944c-1f3b1a7f370e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f16aeeeb-46a3-4d95-89f8-c127e36ef64a")>]

# %%
details11=[]
for i in detail11:
    details11.append(i.text.replace('/month\n',' '))
details11
# Out:
# ['₹6,671 ₹2,99,899',
#  '₹15,349 ₹6,89,999',
#  '₹8,008 ₹3,59,999',
#  '₹8,435 ₹3,79,199',
#  '₹7,984 ₹3,58,899',
#  '₹8,684 ₹3,90,399',
#  '₹15,326 ₹6,88,999',
#  '₹16,161 ₹7,26,499',
#  '₹14,523 ₹6,52,899',
#  '₹9,409 ₹4,22,999',
#  '₹10,261 ₹4,61,299',
#  '₹13,727 ₹6,17,099',
#  '₹37,457 ₹16,83,899',
#  '₹14,288 ₹6,42,299',
#  '₹9,100 ₹4,09,099',
#  '₹33,551 ₹15,08,299',
#  '₹11,774 ₹5,29,299',
#  '₹13,249 ₹5,95,599',
#  '₹11,514 ₹5,17,599',
#  '₹8,537 ₹3,83,799',
#  '₹6,495 ₹2,91,999',
#  '₹14,176 ₹6,37,299',
#  '₹38,634 ₹17,36,799',
#  '₹23,348 ₹10,49,599',
#  '₹11,189 ₹5,02,999',
#  '₹9,412 ₹4,23,099',
#  '₹11,427 ₹5,13,699',
#  '₹11,919 ₹5,35,799',
#  '₹16,643 ₹7,48,199',
#  '₹10,889 ₹4,89,499',
#  '₹12,199 ₹5,48,399',
#  '₹6,960 ₹3,12,899',
#  '₹36,743 ₹16,51,799',
#  '₹11,529 ₹5,18,299',
#  '₹28,442 ₹12,78,599',
#  '₹35,066 ₹15,76,399',
#  '₹11,222 ₹5,04,499',
#  '₹8,811 ₹3,96,099',
#  '₹11,967 ₹5,37,999',
#  '₹47,999 ₹21,57,799',
#  '₹18,465 ₹8,30,099',
# ...

# %%
downpayment1=[]
for i in detail11:
    downpayment1.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment1
# Out:
# ['6671',
#  '15349',
#  '8008',
#  '8435',
#  '7984',
#  '8684',
#  '15326',
#  '16161',
#  '14523',
#  '9409',
#  '10261',
#  '13727',
#  '37457',
#  '14288',
#  '9100',
#  '33551',
#  '11774',
#  '13249',
#  '11514',
#  '8537',
#  '6495',
#  '14176',
#  '38634',
#  '23348',
#  '11189',
#  '9412',
#  '11427',
#  '11919',
#  '16643',
#  '10889',
#  '12199',
#  '6960',
#  '36743',
#  '11529',
#  '28442',
#  '35066',
#  '11222',
#  '8811',
#  '11967',
#  '47999',
#  '18465',
#  '11856',
#  '22769',
#  '13729',
#  '11218',
#  '12034',
#  '10596',
#  '12842',
#  '11999',
#  '18797',
#  '12190',
#  '8215',
#  '9005',
#  '26446',
#  '11256',
#  '18280',
#  '14161',
#  '10108',
#  '12490',
#  '15602',
#  '15889',
#  '12239',
#  '8257',
#  '10551',
#  '14305',
#  '11707',
#  '13320',
#  '11013',
#  '9218',
#  '10361',
#  '14939',
#  '12619',
#  '14317',
#  '15091',
#  '16005',
#  '11761',
#  '13051',
#  '35896',
#  '13251',
#  '8631',
#  '9085',
#  '9808',
#  '9618',
#  '43648',
#  '14592',
# ...

# %%
price1=[]
for i in detail11:
    price1.append(i.text.split()[-1].replace('₹','').replace(',',''))
price1
# Out:
# ['299899',
#  '689999',
#  '359999',
#  '379199',
#  '358899',
#  '390399',
#  '688999',
#  '726499',
#  '652899',
#  '422999',
#  '461299',
#  '617099',
#  '1683899',
#  '642299',
#  '409099',
#  '1508299',
#  '529299',
#  '595599',
#  '517599',
#  '383799',
#  '291999',
#  '637299',
#  '1736799',
#  '1049599',
#  '502999',
#  '423099',
#  '513699',
#  '535799',
#  '748199',
#  '489499',
#  '548399',
#  '312899',
#  '1651799',
#  '518299',
#  '1278599',
#  '1576399',
#  '504499',
#  '396099',
#  '537999',
#  '2157799',
#  '830099',
#  '532999',
#  '1023599',
#  '617199',
#  '504299',
#  '540999',
#  '476349',
#  '577299',
#  '539399',
#  '844999',
#  '547999',
#  '369299',
#  '404799',
#  '1188899',
#  '505999',
#  '821799',
#  '636599',
#  '454399',
#  '561499',
#  '701399',
#  '714299',
#  '550199',
#  '371199',
#  '474299',
#  '643099',
#  '526299',
#  '598799',
#  '495099',
#  '414399',
#  '465799',
#  '671599',
#  '567299',
#  '643599',
#  '678399',
#  '719499',
#  '528699',
# ...

# %%
locationchange2=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange2
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange2.click()

# %%
gurgoan=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[3]')
gurgoan
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="5b490276-b647-4830-89da-c3b0e67d7b68")>

# %%
gurgoan.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname2=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="a80106f7-afbb-4bb2-ab06-ac222bb6cf1d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="09a3637c-6031-46ff-b667-ac6175fbfbfa")>]

# %%
carnames2=[]
for i in carname2:
    carnames2.append(i.text.split()[1:])
carnames2
# Out:
# [['Jeep', 'Compass'],
#  ['Skoda', 'Rapid'],
#  ['Jeep', 'Compass'],
#  ['Maruti', 'Baleno'],
#  ['Hyundai', 'i20'],
#  ['MG', 'HECTOR'],
#  ['Jeep', 'Compass'],
#  ['Audi', 'A3'],
#  ['Honda', 'City'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Alto', '800'],
#  ['Honda', 'City'],
#  ['MG', 'HECTOR'],
#  ['Renault', 'Kwid'],
#  ['Jeep', 'Compass'],
#  ['MG', 'HECTOR', 'PLUS'],
#  ['Maruti', 'Baleno'],
#  ['Hyundai', 'VENUE'],
#  ['KIA', 'SELTOS'],
#  ['MG', 'HECTOR'],
#  ['Hyundai', 'Verna'],
#  ['Jaguar', 'XF'],
#  ['Hyundai', 'NEW', 'SANTRO'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Hyundai', 'i10'],
#  ['Maruti', 'Baleno'],
#  ['Renault', 'Kwid'],
#  ['Honda', 'City'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['MG', 'HECTOR'],
#  ['Maruti', 'Ciaz'],
#  ['Hyundai', 'VENUE'],
#  ['BMW', 'X1'],
#  ['Ford', 'Endeavour'],
#  ['Maruti', 'Alto', 'K10'],
#  ['Mercedes', 'Benz', 'E', 'Class'],
#  ['MG', 'HECTOR'],
#  ['Toyota', 'Fortuner'],
#  ['Nissan', 'Micra'],
#  ['Tata', 'Tiago'],
# ...

# %%
len(carnames2)
# Out:
# 664

# %%
year2=[]
for i in carname2:
    year2.append(i.text.split()[0])
year2
# Out:
# ['2018',
#  '2020',
#  '2019',
#  '2018',
#  '2010',
#  '2019',
#  '2017',
#  '2014',
#  '2010',
#  '2015',
#  '2013',
#  '2016',
#  '2019',
#  '2018',
#  '2017',
#  '2020',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2019',
#  '2013',
#  '2019',
#  '2019',
#  '2009',
#  '2020',
#  '2019',
#  '2014',
#  '2017',
#  '2020',
#  '2021',
#  '2021',
#  '2016',
#  '2016',
#  '2011',
#  '2013',
#  '2019',
#  '2015',
#  '2014',
#  '2019',
#  '2021',
#  '2019',
#  '2021',
#  '2020',
#  '2021',
#  '2021',
#  '2013',
#  '2019',
#  '2019',
#  '2021',
#  '2018',
#  '2019',
#  '2011',
#  '2018',
#  '2020',
#  '2021',
#  '2014',
#  '2013',
#  '2017',
#  '2019',
#  '2017',
#  '2017',
#  '2017',
#  '2020',
#  '2014',
#  '2020',
#  '2018',
#  '2018',
#  '2020',
#  '2016',
#  '2015',
#  '2017',
#  '2021',
#  '2011',
#  '2018',
#  '2010',
#  '2020',
#  '2017',
#  '2019',
#  '2016',
#  '2021',
#  '2014',
#  '2020',
#  '2016',
#  '2016',
#  '2021',
#  '2014',
#  '2019',
#  '2019',
#  '2019',
# ...

# %%
model2=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="59ab65bd-a029-4d15-bb56-aa3c72561785")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="279baad4-e0a5-4e50-a22f-5789f0f43b1a")>]

# %%
models2=[]
for i in model2:
    models2.append(i.text.replace('Automatic','').replace('Manual',''))
models2
# Out:
# ['2.0 LONGITUDE ',
#  'ACTIVE 1.0 TSI ',
#  '2.0 LIMITED ',
#  'SIGMA 1.2 K12 ',
#  'MAGNA O 1.2 ',
#  'SHARP DCT PETROL ',
#  '2.0 SPORT ',
#  '35TDI PREMIUM ',
#  'S MT PETROL ',
#  'COMFORTLINE 1.2L PETROL ',
#  'LXI ',
#  'SV MT PETROL ',
#  'SUPER DIESEL ',
#  'RXL ',
#  '2.0 LIMITED ',
#  'SHARP HYBRID PETROL ',
#  'DELTA 1.2 K12 ',
#  'S MT 1.2 KAPPA ',
#  'HTK PLUS 1.5 PETROL ',
#  'SHARP 2.0 DIESEL ',
#  '1.6 SX VTVT (O) ',
#  '2.2 DIESEL ',
#  'ERA 1.1 ',
#  'MAGNA 1.2 VTVT ',
#  'ERA 1.1 IRDE ',
#  'SIGMA 1.2 K12 ',
#  'RXT Opt ',
#  'VX MT PETROL ',
#  'SPORTZ 1.2 ',
#  'SHARP DCT PETROL ',
#  'ALPHA 1.5 MT VTVT SHVS ',
#  '1.5 SX CRDI MT ',
#  'SDRIVE 20D ',
#  '2.2l 4X4 MT Trend ',
#  'VXI ',
#  'E 250 CDI AVANTGARDE ',
#  'SHARP DCT PETROL ',
#  '3.0 AT 4X2 ',
#  'XE DIESEL ',
#  'XT 1.2 REVOTRON ',
#  'MID MT',
#  '1.2 MAGNA PLUS VTVT ',
#  '1.0 RXT Opt ',
#  'HTX AT PETROL ',
#  '1.0L Turbo GDI SX MT ',
#  '1.0 CLIMBER OPT AMT ',
#  'ERA 1.4 CRDI ',
# ...

# %%
transmission2=[]
for i in model2:
    transmission2.append(i.text.split()[-1])
transmission2
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'MT',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
# ...

# %%
detail2=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="643eb720-95dd-4e6b-900e-ea8f03b0567c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="6f8dff49-73cb-4c65-8098-a199f4f8f26e")>]

# %%
details2=[]
for i in detail2:
    details2.append(i.text.replace('\n',' '))
details2
# Out:
# ['71,745 km 1st Owner Diesel',
#  '11,399 km 1st Owner Petrol',
#  '46,400 km 1st Owner Diesel',
#  '20,330 km 1st Owner Petrol',
#  '42,422 km 2nd Owner Petrol',
#  '12,267 km 1st Owner Petrol',
#  '62,443 km 1st Owner Diesel',
#  '91,557 km 2nd Owner Diesel',
#  '34,566 km 1st Owner Petrol',
#  '51,495 km 1st Owner Petrol',
#  '12,849 km 2nd Owner Petrol',
#  '45,246 km 1st Owner Petrol',
#  '52,447 km 2nd Owner Diesel',
#  '22,505 km 2nd Owner Petrol',
#  '76,959 km 1st Owner Diesel',
#  '2,775 km 1st Owner Petrol',
#  '23,315 km 3rd Owner Petrol',
#  '21,490 km 1st Owner Petrol',
#  '12,981 km 2nd Owner Petrol',
#  '49,413 km 1st Owner Diesel',
#  '80,631 km 1st Owner Petrol',
#  '28,289 km 2nd Owner Diesel',
#  '11,358 km 1st Owner Petrol',
#  '16,327 km 1st Owner Petrol',
#  '44,319 km 1st Owner Petrol',
#  '35,669 km 1st Owner Petrol',
#  '2,406 km 1st Owner Petrol',
#  '54,517 km 1st Owner Petrol',
#  '30,697 km 3rd Owner Petrol',
#  '8,868 km 1st Owner Petrol',
# ...

# %%
driven2=[]
for i in detail2:
    driven2.append(i.text.split()[0].replace(',',''))
driven2
# Out:
# ['71745',
#  '11399',
#  '46400',
#  '20330',
#  '42422',
#  '12267',
#  '62443',
#  '91557',
#  '34566',
#  '51495',
#  '12849',
#  '45246',
#  '52447',
#  '22505',
#  '76959',
#  '2775',
#  '23315',
#  '21490',
#  '12981',
#  '49413',
#  '80631',
#  '28289',
#  '11358',
#  '16327',
#  '44319',
#  '35669',
#  '2406',
#  '54517',
#  '30697',
#  '8868',
#  '9370',
#  '2213',
#  '30382',
#  '78295',
#  '37580',
#  '42881',
#  '38644',
#  '90086',
#  '63433',
#  '17858',
#  '11828',
#  '22638',
#  '6962',
#  '21784',
#  '29645',
#  '7760',
#  '29974',
#  '25758',
#  '21902',
#  '6344',
#  '22955',
#  '32251',
#  '26475',
#  '27693',
#  '7212',
#  '4536',
#  '82295',
#  '53996',
#  '46437',
#  '16641',
#  '32600',
#  '12855',
#  '78203',
#  '4437',
#  '12511',
#  '13223',
#  '12225',
#  '13278',
#  '31910',
#  '45277',
#  '25238',
#  '40384',
#  '5287',
#  '23874',
#  '19738',
#  '60774',
#  '9928',
#  '36544',
#  '37503',
#  '24828',
#  '6568',
#  '29335',
#  '18191',
#  '28998',
# ...

# %%
owner2=[]
for i in detail2:
    owner2.append(i.text.split()[2])
owner2
# Out:
# ['1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
# ...

# %%
fueltype2=[]
for i in detail2:
    fueltype2.append(i.text.split()[4])
fueltype2
# Out:
# ['Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
detail12=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail12[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="5bc867d7-0098-453d-91be-72c64402636d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="bf9dca3d-b176-42f3-b01c-bec592a1120e")>]

# %%
details12=[]
for i in detail12:
    details12.append(i.text.replace('/month\n',' '))
details12
# Out:
# ['₹28,273 ₹12,70,999',
#  '₹17,433 ₹7,83,699',
#  '₹44,934 ₹20,19,999',
#  '₹11,674 ₹5,24,799',
#  '₹6,015 ₹2,70,399',
#  '₹39,466 ₹17,74,199',
#  '₹21,630 ₹9,72,399',
#  '₹31,207 ₹14,02,899',
#  '₹9,429 ₹4,23,899',
#  '₹9,790 ₹4,40,099',
#  '₹5,695 ₹2,55,999',
#  '₹14,781 ₹6,64,499',
#  '₹35,887 ₹16,13,299',
#  '₹7,174 ₹3,22,499',
#  '₹27,572 ₹12,39,499',
#  '₹40,883 ₹18,37,899',
#  '₹11,976 ₹5,38,399',
#  '₹18,272 ₹8,21,399',
#  '₹25,699 ₹11,55,299',
#  '₹34,984 ₹15,72,699',
#  '₹21,837 ₹9,81,699',
#  '₹36,612 ₹16,45,899',
#  '₹9,765 ₹4,38,999',
#  '₹11,371 ₹5,11,199',
#  '₹4,542 ₹2,04,199',
#  '₹12,426 ₹5,58,599',
#  '₹8,388 ₹3,77,099',
#  '₹14,448 ₹6,49,499',
#  '₹11,629 ₹5,22,799',
#  '₹37,457 ₹16,83,899',
#  '₹26,996 ₹12,13,599',
#  '₹26,994 ₹12,13,499',
#  '₹36,027 ₹16,19,599',
#  '₹36,532 ₹16,42,299',
#  '₹5,339 ₹2,39,999',
#  '₹32,379 ₹14,55,599',
#  '₹38,427 ₹17,27,499',
#  '₹35,097 ₹15,77,799',
#  '₹6,124 ₹2,75,299',
#  '₹10,397 ₹4,67,399',
#  '₹20,596 ₹9,25,899',
# ...

# %%
downpayment2=[]
for i in detail12:
    downpayment2.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment2
# Out:
# ['28273',
#  '17433',
#  '44934',
#  '11674',
#  '6015',
#  '39466',
#  '21630',
#  '31207',
#  '9429',
#  '9790',
#  '5695',
#  '14781',
#  '35887',
#  '7174',
#  '27572',
#  '40883',
#  '11976',
#  '18272',
#  '25699',
#  '34984',
#  '21837',
#  '36612',
#  '9765',
#  '11371',
#  '4542',
#  '12426',
#  '8388',
#  '14448',
#  '11629',
#  '37457',
#  '26996',
#  '26994',
#  '36027',
#  '36532',
#  '5339',
#  '32379',
#  '38427',
#  '35097',
#  '6124',
#  '10397',
#  '20596',
#  '13745',
#  '11127',
#  '31810',
#  '22033',
#  '12379',
#  '6813',
#  '37680',
#  '7683',
#  '18278',
#  '7928',
#  '12466',
#  '5239',
#  '12165',
#  '29156',
#  '26349',
#  '21450',
#  '7910',
#  '42211',
#  '8262',
#  '10337',
#  '13852',
#  '19041',
#  '24362',
#  '7574',
#  '13175',
#  '10866',
#  '19386',
#  '18296',
#  '9543',
#  '9474',
#  '20193',
#  '20247',
#  '6989',
#  '7892',
#  '6651',
#  '32864',
#  '18207',
#  '31327',
#  '15024',
#  '15807',
#  '9231',
#  '24565',
#  '14383',
#  '14439',
# ...

# %%
price2=[]
for i in detail12:
    price2.append(i.text.split()[-1].replace('₹','').replace(',',''))
price2
# Out:
# ['1270999',
#  '783699',
#  '2019999',
#  '524799',
#  '270399',
#  '1774199',
#  '972399',
#  '1402899',
#  '423899',
#  '440099',
#  '255999',
#  '664499',
#  '1613299',
#  '322499',
#  '1239499',
#  '1837899',
#  '538399',
#  '821399',
#  '1155299',
#  '1572699',
#  '981699',
#  '1645899',
#  '438999',
#  '511199',
#  '204199',
#  '558599',
#  '377099',
#  '649499',
#  '522799',
#  '1683899',
#  '1213599',
#  '1213499',
#  '1619599',
#  '1642299',
#  '239999',
#  '1455599',
#  '1727499',
#  '1577799',
#  '275299',
#  '467399',
#  '925899',
#  '617899',
#  '500199',
#  '1429999',
#  '990499',
#  '556499',
#  '306299',
#  '1693899',
#  '345399',
#  '821699',
#  '356399',
#  '560399',
#  '235499',
#  '546899',
#  '1310699',
#  '1184499',
#  '964299',
#  '355599',
#  '1897599',
#  '371399',
#  '464699',
#  '622699',
#  '855999',
#  '1095199',
#  '340499',
#  '592299',
#  '488499',
#  '871499',
#  '822499',
#  '428999',
#  '425899',
#  '907799',
#  '910199',
#  '314199',
#  '354799',
# ...

# %%
locationchange3=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange3
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange3.click()

# %%
pune=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[5]')
pune
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="fe4dcaee-9293-4f9f-bb8f-1a4d4a4aa013")>

# %%
pune.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname3=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="8ad81b2b-34a9-4955-88ba-c21226aa8c96")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="8460bb28-5956-4cd6-ad11-5c6f1ddc4ec1")>]

# %%
carnames3=[]
for i in carname3:
    carnames3.append(i.text.split()[1:])
carnames3
# Out:
# [['Maruti', 'Swift'],
#  ['Hyundai', 'Eon'],
#  ['Maruti', 'Alto', '800'],
#  ['Honda', 'City'],
#  ['Honda', 'Jazz'],
#  ['Maruti', 'Swift'],
#  ['Nissan', 'MAGNITE'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Ertiga'],
#  ['Tata', 'Tiago'],
#  ['Maruti', 'Celerio'],
#  ['Maruti', 'Swift', 'Dzire'],
#  ['Hyundai', 'VENUE'],
#  ['Toyota', 'URBAN', 'CRUISER'],
#  ['Maruti', 'Alto'],
#  ['Mercedes', 'Benz', 'C', 'Class'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Hyundai', 'Xcent'],
#  ['Ford', 'Ecosport'],
#  ['Maruti', 'Celerio'],
#  ['Maruti', 'Swift', 'Dzire'],
#  ['Maruti', 'Alto', 'K10'],
#  ['Maruti', 'Swift', 'Dzire'],
#  ['Maruti', 'S', 'Cross'],
#  ['Maruti', 'Swift'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Celerio'],
#  ['Toyota', 'Etios'],
#  ['Hyundai', 'i20'],
#  ['Hyundai', 'i10'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Tata', 'Tiago'],
#  ['Renault', 'Kwid'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Ciaz'],
#  ['Honda', 'City'],
# ...

# %%
len(carnames3)
# Out:
# 472

# %%
year3=[]
for i in carname3:
    year3.append(i.text.split()[0])
year3
# Out:
# ['2011',
#  '2014',
#  '2015',
#  '2012',
#  '2016',
#  '2016',
#  '2021',
#  '2013',
#  '2019',
#  '2020',
#  '2016',
#  '2012',
#  '2020',
#  '2021',
#  '2020',
#  '2011',
#  '2016',
#  '2017',
#  '2015',
#  '2018',
#  '2015',
#  '2011',
#  '2014',
#  '2021',
#  '2017',
#  '2016',
#  '2017',
#  '2014',
#  '2012',
#  '2013',
#  '2017',
#  '2019',
#  '2018',
#  '2021',
#  '2015',
#  '2016',
#  '2018',
#  '2017',
#  '2016',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2015',
#  '2019',
#  '2020',
#  '2020',
#  '2019',
#  '2013',
#  '2018',
#  '2015',
#  '2021',
#  '2017',
#  '2019',
#  '2016',
#  '2019',
#  '2015',
#  '2016',
#  '2017',
#  '2016',
#  '2019',
#  '2018',
#  '2014',
#  '2019',
#  '2018',
#  '2019',
#  '2017',
#  '2014',
#  '2020',
#  '2018',
#  '2019',
#  '2014',
#  '2016',
#  '2018',
#  '2017',
#  '2012',
#  '2019',
#  '2016',
#  '2018',
#  '2015',
#  '2015',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2016',
#  '2016',
#  '2018',
#  '2019',
# ...

# %%
model3=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="fddb5bb1-0c8b-4147-8fc0-0d90a08e6650")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f9efba7a-99e5-443b-b359-695b324af513")>]

# %%
models3=[]
for i in model3:
    models3.append(i.text.replace('Automatic','').replace('Manual',''))
models3
# Out:
# ['VDI ',
#  'SPORTZ ',
#  'LXI ',
#  'V AT ',
#  'VX 1.2 ',
#  'VXI ',
#  'XL Turbo CVT',
#  'VXI ',
#  'ZXI SMART HYBRID AT ',
#  'XZ+ 1.2 Revotron ',
#  'VDI ',
#  'VDI BS IV ',
#  'SX 1.0 GDI IMT ',
#  'PREMIUM MT',
#  'LXI ',
#  '250 CDI ELEGANCE AT ',
#  'ASTA 1.2 (O) VTVT ',
#  'SX 1.2 OPT ',
#  '1.5 TITANIUMTDCI OPT ',
#  'VXI ',
#  'VXI 1.2 BS IV ',
#  'VXI ',
#  'VXI 1.2 BS IV ',
#  'ZETA SHVS PETROL ',
#  'VDI OPT ',
#  '1.0 RXT ',
#  'VXI AMT ',
#  'CROSS 1.5 V ',
#  'MAGNA O 1.2 ',
#  'SPORTZ 1.2 AT KAPPA2 ',
#  'ERA 1.2 ',
#  'ZDI + AMT ',
#  'XZ 1.2 REVOTRON ',
#  '1.0 RXT Opt ',
#  'GT TSI 1.2 PETROL AT ',
#  'ZXI ',
#  'ZX CVT ANNIVERSARY EDITION ',
#  'ALPHA 1.4 VVT ',
#  '1.2 SX MT I VTEC ',
#  'VXI AMT ',
#  'LXI ',
#  'RXT 1.0 EASY-R AT OPTION ',
#  '2.4 VX 7 STR ',
#  'MAGNA 1.4 CRDI ',
#  'CLIMBER 1.0 AT ',
#  'XZ+ 1.5 ',
#  'S MT 1.2 KAPPA ',
#  'ZDI ',
#  'RX5 ',
#  'RXT 1.0 EASY-R AT OPTION ',
#  'ZXI AT ',
#  'SHARP DCT PETROL ',
#  '1.2 V MT ',
# ...

# %%
transmission3=[]
for i in model3:
    transmission3.append(i.text.split()[-1])
transmission3
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'CVT',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'MT',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
# ...

# %%
detail3=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="456f4ec7-9555-4103-8d3f-a576405a1b2d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="0f61f854-c8ab-421c-aea3-e56bf5475b2f")>]

# %%
details3=[]
for i in detail3:
    details3.append(i.text.replace('\n',' '))
details3
# Out:
# ['1,56,491 km 1st Owner Diesel',
#  '11,779 km 1st Owner Petrol',
#  '11,125 km 1st Owner Petrol',
#  '42,819 km 1st Owner Petrol',
#  '46,309 km 2nd Owner Petrol',
#  '14,724 km 2nd Owner Petrol',
#  '16,049 km 1st Owner Petrol',
#  '40,762 km 2nd Owner Petrol',
#  '39,506 km 1st Owner Petrol',
#  '8,118 km 1st Owner Petrol',
#  '53,508 km 1st Owner Diesel',
#  '1,36,161 km 1st Owner Diesel',
#  '7,736 km 1st Owner Petrol',
#  '1,961 km 1st Owner Petrol',
#  '2,530 km 1st Owner Petrol',
#  '43,482 km 2nd Owner Diesel',
#  '86,297 km 1st Owner Petrol',
#  '13,639 km 1st Owner Petrol',
#  '51,922 km 1st Owner Diesel',
#  '29,583 km 1st Owner Petrol',
#  '91,842 km 1st Owner Petrol',
#  '58,066 km 3rd Owner Petrol',
#  '54,417 km 1st Owner Petrol',
#  '8,228 km 1st Owner Petrol',
#  '53,444 km 2nd Owner Diesel',
#  '46,799 km 1st Owner Petrol',
#  '35,598 km 1st Owner Petrol',
#  '80,847 km 2nd Owner Petrol',
#  '56,711 km 2nd Owner Petrol',
#  '39,557 km 2nd Owner Petrol',
# ...

# %%
driven3=[]
for i in detail3:
    driven3.append(i.text.split()[0].replace(',',''))
driven3
# Out:
# ['156491',
#  '11779',
#  '11125',
#  '42819',
#  '46309',
#  '14724',
#  '16049',
#  '40762',
#  '39506',
#  '8118',
#  '53508',
#  '136161',
#  '7736',
#  '1961',
#  '2530',
#  '43482',
#  '86297',
#  '13639',
#  '51922',
#  '29583',
#  '91842',
#  '58066',
#  '54417',
#  '8228',
#  '53444',
#  '46799',
#  '35598',
#  '80847',
#  '56711',
#  '39557',
#  '33595',
#  '33415',
#  '25710',
#  '5326',
#  '41708',
#  '57437',
#  '16118',
#  '21004',
#  '35472',
#  '22989',
#  '8254',
#  '34507',
#  '37082',
#  '42587',
#  '36707',
#  '20053',
#  '787',
#  '32022',
#  '73784',
#  '48706',
#  '80374',
#  '6249',
#  '15182',
#  '2839',
#  '34366',
#  '42955',
#  '16285',
#  '6397',
#  '53139',
#  '163438',
#  '17525',
#  '82015',
#  '80576',
#  '9981',
#  '28792',
#  '30456',
#  '63687',
#  '61565',
#  '11036',
#  '44195',
#  '56902',
#  '76721',
#  '41171',
#  '11617',
#  '104347',
#  '126134',
#  '15847',
#  '32054',
#  '24337',
#  '42820',
#  '64814',
#  '28225',
#  '81006',
#  '27534',
# ...

# %%
owner3=[]
for i in detail3:
    owner3.append(i.text.split()[2])
owner3
# Out:
# ['1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
# ...

# %%
fueltype3=[]
for i in detail3:
    fueltype3.append(i.text.split()[4])
fueltype3
# Out:
# ['Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
# ...

# %%
detail13=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail13[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1fd6635f-778a-4d73-9fea-79ec024f4f90")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1cc557f2-4b35-4844-bb82-8c9b21903261")>]

# %%
details13=[]
for i in detail13:
    details13.append(i.text.replace('/month\n',' '))
details13
# Out:
# ['₹7,752 ₹3,48,499',
#  '₹7,543 ₹3,39,099',
#  '₹6,524 ₹2,93,299',
#  '₹11,151 ₹5,01,299',
#  '₹10,477 ₹4,70,999',
#  '₹11,220 ₹5,04,399',
#  '₹22,598 ₹10,15,899',
#  '₹8,820 ₹3,96,499',
#  '₹25,158 ₹11,30,999',
#  '₹15,135 ₹6,80,399',
#  '₹9,788 ₹4,39,999',
#  '₹9,162 ₹4,11,899',
#  '₹24,502 ₹11,01,499',
#  '₹26,873 ₹12,08,099',
#  '₹8,958 ₹4,02,699',
#  '₹18,812 ₹8,45,699',
#  '₹9,752 ₹4,38,399',
#  '₹13,760 ₹6,18,599',
#  '₹14,728 ₹6,62,099',
#  '₹11,256 ₹5,05,999',
#  '₹10,551 ₹4,74,299',
#  '₹4,527 ₹2,03,499',
#  '₹9,957 ₹4,47,599',
#  '₹24,847 ₹11,16,999',
#  '₹14,005 ₹6,29,599',
#  '₹7,525 ₹3,38,299',
#  '₹10,410 ₹4,67,999',
#  '₹10,584 ₹4,75,799',
#  '₹8,255 ₹3,71,099',
#  '₹8,504 ₹3,82,299',
#  '₹11,612 ₹5,21,999',
#  '₹21,513 ₹9,67,099',
#  '₹12,283 ₹5,52,199',
#  '₹12,250 ₹5,50,699',
#  '₹15,264 ₹6,86,199',
#  '₹14,256 ₹6,40,899',
#  '₹26,709 ₹12,00,699',
#  '₹17,669 ₹7,94,299',
#  '₹11,503 ₹5,17,099',
#  '₹15,300 ₹6,87,799',
#  '₹7,799 ₹3,50,599',
#  '₹9,794 ₹4,40,299',
# ...

# %%
downpayment3=[]
for i in detail13:
    downpayment3.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment3
# Out:
# ['7752',
#  '7543',
#  '6524',
#  '11151',
#  '10477',
#  '11220',
#  '22598',
#  '8820',
#  '25158',
#  '15135',
#  '9788',
#  '9162',
#  '24502',
#  '26873',
#  '8958',
#  '18812',
#  '9752',
#  '13760',
#  '14728',
#  '11256',
#  '10551',
#  '4527',
#  '9957',
#  '24847',
#  '14005',
#  '7525',
#  '10410',
#  '10584',
#  '8255',
#  '8504',
#  '11612',
#  '21513',
#  '12283',
#  '12250',
#  '15264',
#  '14256',
#  '26709',
#  '17669',
#  '11503',
#  '15300',
#  '7799',
#  '9794',
#  '40365',
#  '13066',
#  '10161',
#  '24598',
#  '19586',
#  '19624',
#  '10962',
#  '9690',
#  '13387',
#  '43866',
#  '13658',
#  '11836',
#  '13698',
#  '17622',
#  '8404',
#  '11832',
#  '10840',
#  '33907',
#  '9994',
#  '15160',
#  '9634',
#  '14984',
#  '11763',
#  '25499',
#  '24896',
#  '8973',
#  '16552',
#  '38659',
#  '18656',
#  '10577',
#  '10197',
#  '7799',
#  '26382',
#  '11051',
#  '14835',
#  '6909',
#  '14292',
#  '19660',
#  '6805',
#  '13118',
#  '10713',
#  '6802',
#  '11614',
# ...

# %%
price3=[]
for i in detail13:
    price3.append(i.text.split()[-1].replace('₹','').replace(',',''))
price3
# Out:
# ['348499',
#  '339099',
#  '293299',
#  '501299',
#  '470999',
#  '504399',
#  '1015899',
#  '396499',
#  '1130999',
#  '680399',
#  '439999',
#  '411899',
#  '1101499',
#  '1208099',
#  '402699',
#  '845699',
#  '438399',
#  '618599',
#  '662099',
#  '505999',
#  '474299',
#  '203499',
#  '447599',
#  '1116999',
#  '629599',
#  '338299',
#  '467999',
#  '475799',
#  '371099',
#  '382299',
#  '521999',
#  '967099',
#  '552199',
#  '550699',
#  '686199',
#  '640899',
#  '1200699',
#  '794299',
#  '517099',
#  '687799',
#  '350599',
#  '440299',
#  '1814599',
#  '587399',
#  '456799',
#  '1105799',
#  '880499',
#  '882199',
#  '492799',
#  '435599',
#  '601799',
#  '1971999',
#  '613999',
#  '532099',
#  '615799',
#  '792199',
#  '377799',
#  '531899',
#  '487299',
#  '1524299',
#  '449299',
#  '681499',
#  '433099',
#  '673599',
#  '528799',
#  '1146299',
#  '1119199',
#  '403399',
#  '744099',
#  '1737899',
#  '838699',
#  '475499',
#  '458399',
#  '350599',
#  '1185999',
# ...

# %%
locationchange4=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange4
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange4.click()

# %%
bengaluru=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[6]')

# %%
bengaluru.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname4=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f04ce44c-b478-41a4-a2bf-532dbc204ee1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="73a14023-5d2a-414e-92ad-3f9c7401c69f")>]

# %%
carnames4=[]
for i in carname4:
    carnames4.append(i.text.split()[1:])
carnames4
# Out:
# [['KIA', 'SELTOS'],
#  ['Maruti', 'Swift'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Renault', 'Duster'],
#  ['Maruti', 'Swift'],
#  ['Ford', 'Figo'],
#  ['Renault', 'Duster'],
#  ['Jeep', 'Compass'],
#  ['Honda', 'City'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Swift'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Honda', 'WR-V'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Honda', 'City'],
#  ['Maruti', 'Celerio'],
#  ['Maruti', 'Alto', 'K10'],
#  ['MG', 'HECTOR'],
#  ['MG', 'HECTOR'],
#  ['Maruti', 'Dzire'],
#  ['MG', 'HECTOR'],
#  ['Hyundai', 'NEW', 'SANTRO'],
#  ['Hyundai', 'Creta'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Tata', 'Tiago'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Ford', 'FREESTYLE'],
#  ['Ford', 'Ecosport'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Swift'],
#  ['Honda', 'Amaze'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Maruti', 'Eeco'],
#  ['Tata', 'Tiago'],
#  ['Maruti', 'Celerio'],
# ...

# %%
len(carnames4)
# Out:
# 457

# %%
year4=[]
for i in carname4:
    year4.append(i.text.split()[0])
year4
# Out:
# ['2021',
#  '2012',
#  '2019',
#  '2019',
#  '2014',
#  '2012',
#  '2017',
#  '2017',
#  '2020',
#  '2014',
#  '2020',
#  '2016',
#  '2019',
#  '2017',
#  '2017',
#  '2017',
#  '2015',
#  '2012',
#  '2019',
#  '2019',
#  '2017',
#  '2019',
#  '2019',
#  '2017',
#  '2014',
#  '2018',
#  '2014',
#  '2015',
#  '2019',
#  '2019',
#  '2010',
#  '2017',
#  '2017',
#  '2013',
#  '2014',
#  '2018',
#  '2017',
#  '2016',
#  '2016',
#  '2020',
#  '2019',
#  '2016',
#  '2019',
#  '2019',
#  '2016',
#  '2014',
#  '2016',
#  '2013',
#  '2019',
#  '2018',
#  '2014',
#  '2014',
#  '2016',
#  '2019',
#  '2017',
#  '2021',
#  '2020',
#  '2016',
#  '2018',
#  '2016',
#  '2015',
#  '2012',
#  '2017',
#  '2015',
#  '2020',
#  '2020',
#  '2016',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2014',
#  '2017',
#  '2014',
#  '2018',
#  '2016',
#  '2015',
#  '2016',
#  '2017',
#  '2017',
#  '2019',
#  '2017',
#  '2018',
#  '2018',
#  '2018',
#  '2019',
#  '2012',
#  '2019',
#  '2021',
#  '2019',
# ...

# %%
model4=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f830b784-71ca-4ef2-8444-1ccf00bd7f80")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="ad905ecd-0e40-4c9b-9085-8e7f743029d4")>]

# %%
models4=[]
for i in model4:
    models4.append(i.text.replace('Automatic','').replace('Manual',''))
models4
# Out:
# ['GTX 1.4 GDI PETROL ',
#  'VXI ',
#  '1.2 SPORTS PLUS VTVT CVT ',
#  'RXS (O) CVT ',
#  'VXI ',
#  '1.2 TITANIUM DURATEC ',
#  'RXS CVT 106 PS ',
#  'LIMITED 1.4 AT ',
#  'V MT PETROL ',
#  'ZXI ',
#  'ZXI + ',
#  'VXI OPT ',
#  'MAGNA+ VTVT ',
#  '1.2 i-VTEC VX MT ',
#  'Magna 1.2 AT VTVT ',
#  'V MT PETROL ',
#  'VXI ',
#  'VXI ',
#  'SHARP 2.0 DIESEL ',
#  'SHARP 2.0 DIESEL ',
#  'ZXI Plus AMT ',
#  'SHARP 2.0 DIESEL ',
#  'ASTA 1.1 MT ',
#  '1.6 SX CRDI ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'XZ 1.2 REVOTRON ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'TITANIUM 1.2 TI-VCT MT ',
#  '1.5 TITANIUM SIGNATURE TI VCT (SUNROOF) ',
#  'VXI ',
#  'ZXI ',
#  'VXI OPT ',
#  '1.2 VXMT I VTEC ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  '5 STR WITH AC PLUSHTR ',
#  'XZ 1.2 REVOTRON ',
#  'VXI ',
#  'ASTA 1.2 (O) VTVT ',
#  'XZ 1.2 ',
#  '1.1 MAGNA MT ',
#  'T (O) ',
#  'VXI ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'SPORTZ 1.2 ',
#  'S MT PETROL ',
#  '1.2 S AT ',
# ...

# %%
transmission4=[]
for i in model4:
    transmission4.append(i.text.split()[-1])
transmission4
# Out:
# ['Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
# ...

# %%
detail4=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="6d47efde-b6f7-4c71-aa09-edd20bf32e77")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="a28dfb75-a2a4-427b-a494-4ae30f6b4cc4")>]

# %%
details4=[]
for i in detail4:
    details4.append(i.text.replace('\n',' '))
details4
# Out:
# ['4,257 km 1st Owner Petrol',
#  '56,391 km 2nd Owner Petrol',
#  '4,834 km 1st Owner Petrol',
#  '18,967 km 1st Owner Petrol',
#  '51,781 km 1st Owner Petrol',
#  '54,944 km 1st Owner Petrol',
#  '31,859 km 2nd Owner Petrol',
#  '22,316 km 1st Owner Petrol',
#  '14,417 km 1st Owner Petrol',
#  '31,258 km 1st Owner Petrol',
#  '14,065 km 1st Owner Petrol',
#  '9,755 km 1st Owner Petrol',
#  '17,302 km 1st Owner Petrol',
#  '43,808 km 1st Owner Petrol',
#  '12,646 km 2nd Owner Petrol',
#  '28,310 km 2nd Owner Petrol',
#  '33,689 km 1st Owner Petrol',
#  '55,334 km 2nd Owner Petrol',
#  '20,909 km 1st Owner Diesel',
#  '30,076 km 1st Owner Diesel',
#  '60,090 km 1st Owner Petrol',
#  '26,225 km 1st Owner Diesel',
#  '36,398 km 1st Owner Petrol',
#  '57,767 km 2nd Owner Diesel',
#  '38,180 km 1st Owner Petrol',
#  '27,780 km 2nd Owner Petrol',
#  '38,596 km 2nd Owner Petrol',
#  '20,067 km 1st Owner Petrol',
#  '33,425 km 1st Owner Petrol',
#  '40,792 km 1st Owner Petrol',
# ...

# %%
driven4=[]
for i in detail4:
    driven4.append(i.text.split()[0].replace(',',''))
driven4
# Out:
# ['4257',
#  '56391',
#  '4834',
#  '18967',
#  '51781',
#  '54944',
#  '31859',
#  '22316',
#  '14417',
#  '31258',
#  '14065',
#  '9755',
#  '17302',
#  '43808',
#  '12646',
#  '28310',
#  '33689',
#  '55334',
#  '20909',
#  '30076',
#  '60090',
#  '26225',
#  '36398',
#  '57767',
#  '38180',
#  '27780',
#  '38596',
#  '20067',
#  '33425',
#  '40792',
#  '27423',
#  '36689',
#  '55090',
#  '47686',
#  '36475',
#  '14769',
#  '11086',
#  '38954',
#  '86760',
#  '8102',
#  '11005',
#  '92484',
#  '79432',
#  '18681',
#  '49527',
#  '57997',
#  '48138',
#  '72439',
#  '12731',
#  '47677',
#  '48877',
#  '44059',
#  '40368',
#  '20246',
#  '71705',
#  '6005',
#  '20352',
#  '41599',
#  '31842',
#  '75483',
#  '40710',
#  '49885',
#  '40600',
#  '95138',
#  '5306',
#  '31304',
#  '51929',
#  '18241',
#  '44911',
#  '46687',
#  '29114',
#  '66021',
#  '71077',
#  '73271',
#  '36498',
#  '39493',
#  '77365',
#  '37215',
#  '62360',
#  '27858',
#  '14345',
#  '59647',
#  '21562',
# ...

# %%
owner4=[]
for i in detail4:
    owner4.append(i.text.split()[2])
owner4
# Out:
# ['1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
# ...

# %%
fueltype4=[]
for i in detail4:
    fueltype4.append(i.text.split()[4])
fueltype4
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
detail14=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail14[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="8190cc45-749c-45e3-9617-6443c5dd86ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1b688ce8-f76b-4add-93df-4e1eefe8236e")>]

# %%
details14=[]
for i in detail14:
    details14.append(i.text.replace('/month\n',' '))
details14
# Out:
# ['₹44,249 ₹19,89,199',
#  '₹9,667 ₹4,34,599',
#  '₹21,146 ₹9,50,599',
#  '₹22,760 ₹10,23,199',
#  '₹10,978 ₹4,93,499',
#  '₹8,362 ₹3,75,899',
#  '₹19,404 ₹8,72,299',
#  '₹37,580 ₹16,89,399',
#  '₹26,602 ₹11,95,899',
#  '₹13,160 ₹5,91,599',
#  '₹23,704 ₹10,65,599',
#  '₹13,676 ₹6,14,799',
#  '₹16,218 ₹7,29,099',
#  '₹17,433 ₹7,83,699',
#  '₹12,940 ₹5,81,699',
#  '₹20,403 ₹9,17,199',
#  '₹10,003 ₹4,49,699',
#  '₹6,139 ₹2,75,999',
#  '₹41,415 ₹18,61,799',
#  '₹42,656 ₹19,17,599',
#  '₹16,650 ₹7,48,499',
#  '₹42,656 ₹19,17,599',
#  '₹13,282 ₹5,97,099',
#  '₹25,230 ₹11,34,199',
#  '₹10,706 ₹4,81,299',
#  '₹12,524 ₹5,62,999',
#  '₹10,733 ₹4,82,499',
#  '₹11,634 ₹5,22,999',
#  '₹16,523 ₹7,42,799',
#  '₹23,917 ₹10,75,199',
#  '₹7,183 ₹3,22,899',
#  '₹15,017 ₹6,75,099',
#  '₹13,614 ₹6,11,999',
#  '₹10,944 ₹4,91,999',
#  '₹10,978 ₹4,93,499',
#  '₹9,623 ₹4,32,599',
#  '₹11,921 ₹5,35,899',
#  '₹10,232 ₹4,59,999',
#  '₹12,112 ₹5,44,499',
#  '₹20,516 ₹9,22,299',
#  '₹11,932 ₹5,36,399',
# ...

# %%
downpayment4=[]
for i in detail14:
    downpayment4.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment4
# Out:
# ['44249',
#  '9667',
#  '21146',
#  '22760',
#  '10978',
#  '8362',
#  '19404',
#  '37580',
#  '26602',
#  '13160',
#  '23704',
#  '13676',
#  '16218',
#  '17433',
#  '12940',
#  '20403',
#  '10003',
#  '6139',
#  '41415',
#  '42656',
#  '16650',
#  '42656',
#  '13282',
#  '25230',
#  '10706',
#  '12524',
#  '10733',
#  '11634',
#  '16523',
#  '23917',
#  '7183',
#  '15017',
#  '13614',
#  '10944',
#  '10978',
#  '9623',
#  '11921',
#  '10232',
#  '12112',
#  '20516',
#  '11932',
#  '6099',
#  '8446',
#  '13362',
#  '13342',
#  '13780',
#  '14141',
#  '8980',
#  '15148',
#  '14532',
#  '10978',
#  '8072',
#  '17193',
#  '14256',
#  '20554',
#  '18134',
#  '14245',
#  '7759',
#  '9205',
#  '11743',
#  '11273',
#  '6660',
#  '19028',
#  '9696',
#  '10918',
#  '9403',
#  '14904',
#  '8482',
#  '10117',
#  '15598',
#  '19215',
#  '7677',
#  '18950',
#  '8958',
#  '18327',
#  '11378',
#  '10043',
#  '8021',
#  '15015',
#  '13280',
#  '10942',
#  '11507',
#  '10535',
#  '9534',
# ...

# %%
price4=[]
for i in detail14:
    price4.append(i.text.split()[-1].replace('₹','').replace(',',''))
price4
# Out:
# ['1989199',
#  '434599',
#  '950599',
#  '1023199',
#  '493499',
#  '375899',
#  '872299',
#  '1689399',
#  '1195899',
#  '591599',
#  '1065599',
#  '614799',
#  '729099',
#  '783699',
#  '581699',
#  '917199',
#  '449699',
#  '275999',
#  '1861799',
#  '1917599',
#  '748499',
#  '1917599',
#  '597099',
#  '1134199',
#  '481299',
#  '562999',
#  '482499',
#  '522999',
#  '742799',
#  '1075199',
#  '322899',
#  '675099',
#  '611999',
#  '491999',
#  '493499',
#  '432599',
#  '535899',
#  '459999',
#  '544499',
#  '922299',
#  '536399',
#  '274199',
#  '379699',
#  '600699',
#  '599799',
#  '619499',
#  '635699',
#  '403699',
#  '680999',
#  '653299',
#  '493499',
#  '362899',
#  '772899',
#  '640899',
#  '923999',
#  '815199',
#  '640399',
#  '348799',
#  '413799',
#  '527899',
#  '506799',
#  '299399',
#  '855399',
#  '435899',
#  '490799',
#  '422699',
#  '669999',
#  '381299',
#  '454799',
#  '701199',
#  '863799',
#  '345099',
#  '851899',
#  '402699',
#  '823899',
#  '511499',
# ...

# %%
locationchange5=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange5
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange5.click()

# %%
noida=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[2]')
noida
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="4d3d12b6-60ec-475e-b583-dc3e0d0d5e2a")>

# %%
noida.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname5=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="b869edfd-6c28-42d2-844c-926334ddcf8f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="78a541eb-4b6a-4d25-8a3a-e8356d00173c")>]

# %%
carnames5=[]
for i in carname5:
    carnames5.append(i.text.split()[1:])
carnames5
# Out:
# [['Maruti', 'S', 'Cross'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'S', 'PRESSO'],
#  ['Hyundai', 'Verna'],
#  ['Ford', 'Ecosport'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Swift'],
#  ['Hyundai', 'Creta'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Maruti', 'Ciaz'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Ciaz'],
#  ['Maruti', 'Swift'],
#  ['Skoda', 'Rapid'],
#  ['Jaguar', 'XF'],
#  ['Jeep', 'Compass'],
#  ['Maruti', 'Baleno'],
#  ['Maruti', 'Alto', '800'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Hyundai', 'VENUE'],
#  ['Jeep', 'Compass'],
#  ['MG', 'HECTOR', 'PLUS'],
#  ['Hyundai', 'i10'],
#  ['Volkswagen', 'Polo'],
#  ['Hyundai', 'i20'],
#  ['Honda', 'City'],
#  ['Hyundai', 'Verna'],
#  ['Honda', 'City'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Jeep', 'Compass'],
# ...

# %%
len(carnames5)
# Out:
# 684

# %%
year5=[]
for i in carname5:
    year5.append(i.text.split()[0])
year5
# Out:
# ['2017',
#  '2015',
#  '2020',
#  '2014',
#  '2017',
#  '2014',
#  '2016',
#  '2013',
#  '2013',
#  '2016',
#  '2016',
#  '2013',
#  '2017',
#  '2015',
#  '2015',
#  '2016',
#  '2013',
#  '2016',
#  '2016',
#  '2015',
#  '2020',
#  '2013',
#  '2019',
#  '2018',
#  '2013',
#  '2020',
#  '2021',
#  '2018',
#  '2020',
#  '2009',
#  '2015',
#  '2010',
#  '2016',
#  '2019',
#  '2014',
#  '2019',
#  '2017',
#  '2014',
#  '2021',
#  '2021',
#  '2015',
#  '2013',
#  '2019',
#  '2017',
#  '2014',
#  '2017',
#  '2021',
#  '2021',
#  '2021',
#  '2018',
#  '2018',
#  '2011',
#  '2019',
#  '2010',
#  '2021',
#  '2018',
#  '2010',
#  '2019',
#  '2010',
#  '2014',
#  '2014',
#  '2011',
#  '2020',
#  '2017',
#  '2011',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2017',
#  '2019',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2018',
#  '2019',
#  '2019',
#  '2019',
#  '2016',
#  '2011',
#  '2016',
#  '2018',
#  '2021',
#  '2016',
#  '2020',
#  '2014',
#  '2021',
#  '2016',
#  '2018',
# ...

# %%
model5=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="c48537bf-eaae-4640-a546-1c5c27366945")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="b6a11f2f-c245-406d-8465-656fb040f732")>]

# %%
models5=[]
for i in model5:
    models5.append(i.text.replace('Automatic','').replace('Manual',''))
models5
# Out:
# ['ALPHA SHVS ',
#  'LDI BS IV ',
#  'VXI ',
#  'FLUIDIC 1.6 SX CRDI ',
#  '1.5 TDCI TITANIUM PLUS ',
#  'SPORTZ (O) 1.4 ',
#  'VDI OPT ',
#  'VDI ',
#  'VDI ',
#  'VDI ABS ',
#  'VDI ',
#  'VDI ',
#  '1.4 S CRDI ',
#  'ASTA 1.4 CRDI ',
#  'VDI (O) SHVS HYBIRD ',
#  'ZDI PLUS ',
#  'VDI ',
#  'VDI ',
#  'VDI+ SHVS ',
#  'VDI ',
#  'ACTIVE 1.0 TSI ',
#  '2.2 DIESEL ',
#  '2.0 LIMITED ',
#  'SIGMA 1.2 K12 ',
#  'LXI ',
#  'MAGNA 1.2 VTVT ',
#  'S MT 1.2 KAPPA ',
#  '2.0 LONGITUDE ',
#  'SHARP HYBRID PETROL ',
#  'ERA 1.1 IRDE ',
#  'COMFORTLINE 1.2L PETROL ',
#  'MAGNA O 1.2 ',
#  'SV MT PETROL ',
#  '1.6 SX VTVT (O) ',
#  'VX MT PETROL ',
#  'MAGNA 1.2 VTVT ',
#  '2.0 SPORT ',
#  'XE DIESEL ',
#  'ALPHA 1.5 MT VTVT SHVS ',
#  '1.5 SX CRDI MT ',
#  '3.0 AT 4X2 ',
#  'E 250 CDI AVANTGARDE ',
#  'SHARP DCT PETROL ',
#  '2.0 LIMITED ',
#  'LXI ',
#  '2.7 ZX AT 7 STR ',
#  'MID MT',
#  'RXT 1.0 AMT ',
#  '1.0L Turbo GDI SX MT ',
#  'Magna Executive 1.2 ',
#  'RXL ',
#  'VXI ',
# ...

# %%
transmission5=[]
for i in model5:
    transmission5.append(i.text.split()[-1])
transmission5
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'MT',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
# ...

# %%
detail5=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="bc0eb69c-0656-4f6f-8d36-51e5b2f80fa4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="c4eca07c-194d-4967-8f7f-41ac4a1e7fea")>]

# %%
details5=[]
for i in detail5:
    details5.append(i.text.replace('\n',' '))
details5
# Out:
# ['40,129 km 1st Owner Diesel',
#  '49,562 km 1st Owner Diesel',
#  '6,879 km 1st Owner Petrol',
#  '48,513 km 1st Owner Diesel',
#  '42,240 km 1st Owner Diesel',
#  '73,060 km 1st Owner Diesel',
#  '65,905 km 1st Owner Diesel',
#  '44,096 km 1st Owner Diesel',
#  '1,44,580 km 2nd Owner Diesel',
#  '1,06,422 km 1st Owner Diesel',
#  '71,077 km 1st Owner Diesel',
#  '1,12,415 km 1st Owner Diesel',
#  '85,928 km 1st Owner Diesel',
#  '73,516 km 2nd Owner Diesel',
#  '1,22,636 km 1st Owner Diesel',
#  '72,145 km 1st Owner Diesel',
#  '23,952 km 1st Owner Diesel',
#  '79,409 km 2nd Owner Diesel',
#  '88,082 km 1st Owner Diesel',
#  '30,766 km 1st Owner Diesel',
#  '11,399 km 1st Owner Petrol',
#  '28,289 km 2nd Owner Diesel',
#  '46,400 km 1st Owner Diesel',
#  '20,330 km 1st Owner Petrol',
#  '12,849 km 2nd Owner Petrol',
#  '13,223 km 2nd Owner Petrol',
#  '21,490 km 1st Owner Petrol',
#  '71,745 km 1st Owner Diesel',
#  '2,775 km 1st Owner Petrol',
#  '44,319 km 1st Owner Petrol',
# ...

# %%
driven5=[]
for i in detail5:
    driven5.append(i.text.split()[0].replace(',',''))
driven5
# Out:
# ['40129',
#  '49562',
#  '6879',
#  '48513',
#  '42240',
#  '73060',
#  '65905',
#  '44096',
#  '144580',
#  '106422',
#  '71077',
#  '112415',
#  '85928',
#  '73516',
#  '122636',
#  '72145',
#  '23952',
#  '79409',
#  '88082',
#  '30766',
#  '11399',
#  '28289',
#  '46400',
#  '20330',
#  '12849',
#  '13223',
#  '21490',
#  '71745',
#  '2775',
#  '44319',
#  '51495',
#  '42422',
#  '45246',
#  '80631',
#  '54517',
#  '16327',
#  '62443',
#  '63433',
#  '9370',
#  '2213',
#  '90086',
#  '42881',
#  '12267',
#  '76959',
#  '26866',
#  '84205',
#  '11828',
#  '6344',
#  '29645',
#  '27693',
#  '22505',
#  '26475',
#  '17858',
#  '60774',
#  '4536',
#  '23315',
#  '34566',
#  '22638',
#  '48915',
#  '82295',
#  '12511',
#  '66782',
#  '7212',
#  '78203',
#  '37580',
#  '5287',
#  '35669',
#  '8868',
#  '31910',
#  '12855',
#  '52447',
#  '46877',
#  '12476',
#  '11358',
#  '49413',
#  '13278',
#  '61780',
#  '37503',
#  '32251',
#  '24828',
#  '23874',
#  '19360',
#  '23733',
# ...

# %%
owner5=[]
for i in detail5:
    owner5.append(i.text.split()[2])
owner5
# Out:
# ['1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
# ...

# %%
fueltype5=[]
for i in detail5:
    fueltype5.append(i.text.split()[4])
fueltype5
# Out:
# ['Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
# ...

# %%
detail15=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail15[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="af643cd6-ee86-40a4-aa7f-423021383c10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="76d08e13-53a4-492b-b3fd-582db2182b8b")>]

# %%
details15=[]
for i in detail15:
    details15.append(i.text.replace('/month\n',' '))
details15
# Out:
# ['₹20,516 ₹9,22,299',
#  '₹8,675 ₹3,89,999',
#  '₹9,910 ₹4,45,499',
#  '₹11,202 ₹5,03,599',
#  '₹16,154 ₹7,26,199',
#  '₹9,963 ₹4,47,899',
#  '₹14,321 ₹6,43,799',
#  '₹7,723 ₹3,47,199',
#  '₹6,887 ₹3,09,599',
#  '₹9,492 ₹4,26,699',
#  '₹13,502 ₹6,06,999',
#  '₹6,787 ₹3,05,099',
#  '₹17,671 ₹7,94,399',
#  '₹12,137 ₹5,45,599',
#  '₹11,100 ₹4,98,999',
#  '₹15,518 ₹6,97,599',
#  '₹7,632 ₹3,43,099',
#  '₹13,295 ₹5,97,699',
#  '₹12,332 ₹5,54,399',
#  '₹9,794 ₹4,40,299',
#  '₹17,433 ₹7,83,699',
#  '₹36,612 ₹16,45,899',
#  '₹44,934 ₹20,19,999',
#  '₹11,674 ₹5,24,799',
#  '₹5,695 ₹2,55,999',
#  '₹13,175 ₹5,92,299',
#  '₹18,272 ₹8,21,399',
#  '₹28,273 ₹12,70,999',
#  '₹40,883 ₹18,37,899',
#  '₹4,542 ₹2,04,199',
#  '₹9,790 ₹4,40,099',
#  '₹6,015 ₹2,70,399',
#  '₹14,781 ₹6,64,499',
#  '₹21,837 ₹9,81,699',
#  '₹14,448 ₹6,49,499',
#  '₹11,371 ₹5,11,199',
#  '₹21,630 ₹9,72,399',
#  '₹6,124 ₹2,75,299',
#  '₹26,996 ₹12,13,599',
#  '₹26,994 ₹12,13,499',
#  '₹35,097 ₹15,77,799',
# ...

# %%
downpayment5=[]
for i in detail15:
    downpayment5.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment5
# Out:
# ['20516',
#  '8675',
#  '9910',
#  '11202',
#  '16154',
#  '9963',
#  '14321',
#  '7723',
#  '6887',
#  '9492',
#  '13502',
#  '6787',
#  '17671',
#  '12137',
#  '11100',
#  '15518',
#  '7632',
#  '13295',
#  '12332',
#  '9794',
#  '17433',
#  '36612',
#  '44934',
#  '11674',
#  '5695',
#  '13175',
#  '18272',
#  '28273',
#  '40883',
#  '4542',
#  '9790',
#  '6015',
#  '14781',
#  '21837',
#  '14448',
#  '11371',
#  '21630',
#  '6124',
#  '26996',
#  '26994',
#  '35097',
#  '32379',
#  '39466',
#  '27572',
#  '7832',
#  '31347',
#  '20596',
#  '18278',
#  '22033',
#  '12165',
#  '7174',
#  '5239',
#  '10397',
#  '6651',
#  '26349',
#  '11976',
#  '9429',
#  '13745',
#  '5430',
#  '21450',
#  '7574',
#  '6420',
#  '29156',
#  '19041',
#  '5339',
#  '20247',
#  '12426',
#  '37457',
#  '18296',
#  '13852',
#  '35887',
#  '21384',
#  '20574',
#  '9765',
#  '34984',
#  '19386',
#  '19840',
#  '31327',
#  '12466',
#  '15024',
#  '6989',
#  '10853',
#  '13627',
#  '47054',
#  '14383',
# ...

# %%
price5=[]
for i in detail15:
    price5.append(i.text.split()[-1].replace('₹','').replace(',',''))
price5
# Out:
# ['922299',
#  '389999',
#  '445499',
#  '503599',
#  '726199',
#  '447899',
#  '643799',
#  '347199',
#  '309599',
#  '426699',
#  '606999',
#  '305099',
#  '794399',
#  '545599',
#  '498999',
#  '697599',
#  '343099',
#  '597699',
#  '554399',
#  '440299',
#  '783699',
#  '1645899',
#  '2019999',
#  '524799',
#  '255999',
#  '592299',
#  '821399',
#  '1270999',
#  '1837899',
#  '204199',
#  '440099',
#  '270399',
#  '664499',
#  '981699',
#  '649499',
#  '511199',
#  '972399',
#  '275299',
#  '1213599',
#  '1213499',
#  '1577799',
#  '1455599',
#  '1774199',
#  '1239499',
#  '352099',
#  '1409199',
#  '925899',
#  '821699',
#  '990499',
#  '546899',
#  '322499',
#  '235499',
#  '467399',
#  '298999',
#  '1184499',
#  '538399',
#  '423899',
#  '617899',
#  '244099',
#  '964299',
#  '340499',
#  '288599',
#  '1310699',
#  '855999',
#  '239999',
#  '910199',
#  '558599',
#  '1683899',
#  '822499',
#  '622699',
#  '1613299',
#  '961299',
#  '924899',
#  '438999',
#  '1572699',
# ...

# %%
locationchange6=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange6
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange6.click()

# %%
chennai=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[8]')
chennai
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="3c6c4540-1d5d-4a16-b966-ba141980c325")>

# %%
chennai.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname6=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="5ed4f713-73cb-48b0-95d3-8a981c5b2d36")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="67655763-6451-41e2-8c0b-5d8205dfc3a0")>]

# %%
carnames6=[]
for i in carname6:
    carnames6.append(i.text.split()[1:])
carnames6
# Out:
# [['Tata', 'ALTROZ'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Honda', 'Brio'],
#  ['Maruti', 'Swift'],
#  ['Hyundai', 'VENUE'],
#  ['Mercedes', 'Benz', 'C', 'Class'],
#  ['Maruti', 'Celerio'],
#  ['Hyundai', 'NEW', 'SANTRO'],
#  ['Hyundai', 'GRAND', 'I10', 'NIOS'],
#  ['Volkswagen', 'Polo'],
#  ['Hyundai', 'i10'],
#  ['Maruti', 'Eeco'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Hyundai', 'NEW', 'SANTRO'],
#  ['Maruti', 'Eeco'],
#  ['Tata', 'Tiago'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Eeco'],
#  ['Maruti', 'Baleno'],
#  ['Honda', 'City'],
#  ['Tata', 'ALTROZ'],
#  ['Hyundai', 'Xcent'],
#  ['Maruti', 'Alto', '800'],
#  ['Maruti', 'Celerio'],
#  ['Jeep', 'Compass'],
#  ['Maruti', 'Swift'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Celerio'],
#  ['Mahindra', 'MARAZZO'],
#  ['Honda', 'City'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Eeco'],
#  ['Honda', 'Amaze'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
# ...

# %%
len(carnames6)
# Out:
# 525

# %%
year6=[]
for i in carname6:
    year6.append(i.text.split()[0])
year6
# Out:
# ['2021',
#  '2021',
#  '2012',
#  '2019',
#  '2020',
#  '2015',
#  '2020',
#  '2020',
#  '2020',
#  '2014',
#  '2014',
#  '2019',
#  '2020',
#  '2012',
#  '2019',
#  '2018',
#  '2016',
#  '2016',
#  '2019',
#  '2019',
#  '2016',
#  '2017',
#  '2020',
#  '2014',
#  '2018',
#  '2014',
#  '2019',
#  '2015',
#  '2021',
#  '2019',
#  '2018',
#  '2019',
#  '2017',
#  '2019',
#  '2017',
#  '2014',
#  '2017',
#  '2015',
#  '2016',
#  '2014',
#  '2014',
#  '2017',
#  '2018',
#  '2014',
#  '2016',
#  '2020',
#  '2019',
#  '2016',
#  '2016',
#  '2012',
#  '2016',
#  '2019',
#  '2016',
#  '2016',
#  '2019',
#  '2016',
#  '2014',
#  '2020',
#  '2015',
#  '2020',
#  '2018',
#  '2016',
#  '2017',
#  '2013',
#  '2017',
#  '2020',
#  '2015',
#  '2015',
#  '2020',
#  '2016',
#  '2018',
#  '2018',
#  '2018',
#  '2014',
#  '2019',
#  '2021',
#  '2017',
#  '2014',
#  '2020',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2019',
#  '2018',
#  '2017',
#  '2015',
#  '2015',
#  '2016',
#  '2017',
# ...

# %%
model6=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="4266ce61-4f8f-4750-8a84-287e317a8360")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="a205ddcb-38b2-4207-99e4-1484263b91fb")>]

# %%
models6=[]
for i in model6:
    models6.append(i.text.replace('Automatic','').replace('Manual',''))
models6
# Out:
# ['XM+ 1.2 RTN',
#  'VXI ',
#  '1.2 V MT I VTEC ',
#  'LXI ',
#  'S MT 1.2 KAPPA ',
#  'C 200 AVANTGARDE ',
#  'Tour H2 ',
#  'SPORTZ 1.1 ',
#  'SPORTZ PETROL ',
#  'TRENDLINE 1.5L DIESEL ',
#  'MAGNA 1.1 IRDE2 ',
#  '5 STR WITH AC PLUSHTR ',
#  'HIGH LINE PLUS 1.0 ',
#  'VXI ',
#  '1.1 SPORTS AMT ',
#  '5 STR WITH AC PLUSHTR ',
#  'XZ 1.2 REVOTRON ',
#  'VXI OPT ',
#  'VXI AMT ',
#  '5 STR WITH AC PLUSHTR ',
#  'ZETA 1.2 K12 ',
#  'VX MT PETROL ',
#  'XZ 1.2 ',
#  'S 1.2 ',
#  'LXI ',
#  'VXI ',
#  'LIMITED PLUS 2.0 4*4 ',
#  'VXI ',
#  '1.0 RXT Opt ',
#  'VXI ',
#  'M8 7 STR ',
#  'V CVT ',
#  'VXI ',
#  '5 STR WITH AC PLUSHTR ',
#  '1.2 SMT I VTEC ',
#  'VXI ',
#  'VXI OPT AMT ',
#  'VXI AMT ',
#  'VXI OPT ',
#  'VXI ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'ZXI AMT ',
#  'VXI ',
#  'MAGNA PLUS ',
#  'MAGNA 1.2 KAPPA VTVT ',
#  'SPORTZ 1.1 ',
#  '2WD AT GL DIESEL ',
#  '1.2 V AT ',
#  'K2 6 STR ',
#  '1.2 E MT I VTEC ',
#  'ZXI OPT AMT ',
#  'V MT PETROL ',
#  '1.5 TITANIUM TI VCT ',
# ...

# %%
transmission6=[]
for i in model6:
    transmission6.append(i.text.split()[-1])
transmission6
# Out:
# ['RTN',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'RXZ',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
# ...

# %%
detail6=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1be3f3b2-5a09-4669-a72b-2f60544af68a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="764a5b5a-e5ee-4281-a831-9b0c27db51cf")>]

# %%
details6=[]
for i in detail6:
    details6.append(i.text.replace('\n',' '))
details6
# Out:
# ['9,555 km 2nd Owner Petrol',
#  '7,573 km 1st Owner Petrol',
#  '78,914 km 1st Owner Petrol',
#  '54,157 km 1st Owner Petrol',
#  '8,600 km 1st Owner Petrol',
#  '40,861 km 2nd Owner Petrol',
#  '7,652 km 1st Owner Petrol',
#  '8,243 km 1st Owner Petrol',
#  '4,428 km 1st Owner Petrol',
#  '87,566 km 2nd Owner Diesel',
#  '63,251 km 1st Owner Petrol',
#  '3,449 km 1st Owner Petrol',
#  '20,731 km 1st Owner Petrol',
#  '30,885 km 1st Owner Petrol',
#  '17,535 km 2nd Owner Petrol',
#  '11,586 km 1st Owner Petrol',
#  '32,730 km 2nd Owner Petrol',
#  '32,620 km 1st Owner Petrol',
#  '32,429 km 1st Owner Petrol',
#  '5,310 km 2nd Owner Petrol',
#  '41,068 km 1st Owner Petrol',
#  '49,931 km 2nd Owner Petrol',
#  '29,838 km 1st Owner Petrol',
#  '68,256 km 1st Owner Petrol',
#  '7,657 km 2nd Owner Petrol',
#  '32,442 km 1st Owner Petrol',
#  '34,502 km 1st Owner Diesel',
#  '51,079 km 2nd Owner Petrol',
#  '4,352 km 1st Owner Petrol',
#  '3,105 km 1st Owner Petrol',
# ...

# %%
driven6=[]
for i in detail6:
    driven6.append(i.text.split()[0].replace(',',''))
driven6
# Out:
# ['9555',
#  '7573',
#  '78914',
#  '54157',
#  '8600',
#  '40861',
#  '7652',
#  '8243',
#  '4428',
#  '87566',
#  '63251',
#  '3449',
#  '20731',
#  '30885',
#  '17535',
#  '11586',
#  '32730',
#  '32620',
#  '32429',
#  '5310',
#  '41068',
#  '49931',
#  '29838',
#  '68256',
#  '7657',
#  '32442',
#  '34502',
#  '51079',
#  '4352',
#  '3105',
#  '32683',
#  '32644',
#  '38695',
#  '21908',
#  '23338',
#  '31348',
#  '28852',
#  '130482',
#  '30007',
#  '30457',
#  '34714',
#  '88268',
#  '13792',
#  '42875',
#  '16179',
#  '8486',
#  '18527',
#  '51433',
#  '31871',
#  '43569',
#  '73966',
#  '15526',
#  '25112',
#  '23666',
#  '24273',
#  '62059',
#  '57811',
#  '10732',
#  '40077',
#  '10977',
#  '12771',
#  '85486',
#  '41221',
#  '120225',
#  '51654',
#  '20417',
#  '41835',
#  '38791',
#  '23281',
#  '277250',
#  '9142',
#  '58464',
#  '20474',
#  '75080',
#  '10757',
#  '729',
#  '41445',
#  '80666',
#  '8950',
#  '43715',
#  '25303',
#  '76710',
#  '85464',
#  '22713',
# ...

# %%
owner6=[]
for i in detail6:
    owner6.append(i.text.split()[2])
owner6
# Out:
# ['2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
# ...

# %%
fueltype6=[]
for i in detail6:
    fueltype6.append(i.text.split()[4])
fueltype6
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
# ...

# %%
detail16=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail16[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="06444b0b-82e6-4513-a663-0afcef9aa045")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="589d949b-7b3d-4efa-a594-ef121ba5d22b")>]

# %%
details16=[]
for i in detail16:
    details16.append(i.text.replace('/month\n',' '))
details16
# Out:
# ['₹17,542 ₹7,88,599',
#  '₹20,449 ₹9,19,299',
#  '₹8,075 ₹3,62,999',
#  '₹13,109 ₹5,89,299',
#  '₹19,324 ₹8,68,699',
#  '₹50,978 ₹22,91,699',
#  '₹10,862 ₹4,88,299',
#  '₹12,570 ₹5,65,099',
#  '₹14,768 ₹6,63,899',
#  '₹9,211 ₹4,14,099',
#  '₹7,523 ₹3,38,199',
#  '₹10,230 ₹4,59,899',
#  '₹18,832 ₹8,46,599',
#  '₹7,347 ₹3,30,299',
#  '₹13,309 ₹5,98,299',
#  '₹10,482 ₹4,71,199',
#  '₹10,435 ₹4,69,099',
#  '₹12,584 ₹5,65,699',
#  '₹16,281 ₹7,31,899',
#  '₹9,745 ₹4,38,099',
#  '₹12,917 ₹5,80,699',
#  '₹20,040 ₹9,00,899',
#  '₹16,955 ₹7,62,199',
#  '₹9,734 ₹4,37,599',
#  '₹7,601 ₹3,41,699',
#  '₹8,593 ₹3,86,299',
#  '₹50,455 ₹22,68,199',
#  '₹10,341 ₹4,64,899',
#  '₹11,218 ₹5,04,299',
#  '₹12,074 ₹5,42,799',
#  '₹24,889 ₹11,18,899',
#  '₹22,758 ₹10,23,099',
#  '₹12,510 ₹5,62,399',
#  '₹10,891 ₹4,89,599',
#  '₹12,788 ₹5,74,899',
#  '₹8,815 ₹3,96,299',
#  '₹10,993 ₹4,94,199',
#  '₹8,297 ₹3,72,999',
#  '₹12,468 ₹5,60,499',
#  '₹8,673 ₹3,89,899',
#  '₹9,467 ₹4,25,599',
#  '₹10,671 ₹4,79,699',
# ...

# %%
downpayment6=[]
for i in detail16:
    downpayment6.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment6
# Out:
# ['17542',
#  '20449',
#  '8075',
#  '13109',
#  '19324',
#  '50978',
#  '10862',
#  '12570',
#  '14768',
#  '9211',
#  '7523',
#  '10230',
#  '18832',
#  '7347',
#  '13309',
#  '10482',
#  '10435',
#  '12584',
#  '16281',
#  '9745',
#  '12917',
#  '20040',
#  '16955',
#  '9734',
#  '7601',
#  '8593',
#  '50455',
#  '10341',
#  '11218',
#  '12074',
#  '24889',
#  '22758',
#  '12510',
#  '10891',
#  '12788',
#  '8815',
#  '10993',
#  '8297',
#  '12468',
#  '8673',
#  '9467',
#  '10671',
#  '15266',
#  '6486',
#  '9939',
#  '12570',
#  '51487',
#  '13313',
#  '8907',
#  '7229',
#  '10577',
#  '21590',
#  '15142',
#  '6515',
#  '14806',
#  '10935',
#  '4900',
#  '15311',
#  '6446',
#  '19794',
#  '10502',
#  '15676',
#  '14530',
#  '9905',
#  '14928',
#  '30506',
#  '9445',
#  '6929',
#  '26300',
#  '33478',
#  '8175',
#  '20000',
#  '10397',
#  '13473',
#  '10987',
#  '9885',
#  '14530',
#  '11603',
#  '40116',
#  '16677',
#  '13378',
#  '9801',
#  '14523',
#  '17233',
#  '10482',
# ...

# %%
price6=[]
for i in detail16:
    price6.append(i.text.split()[-1].replace('₹','').replace(',',''))
price6
# Out:
# ['788599',
#  '919299',
#  '362999',
#  '589299',
#  '868699',
#  '2291699',
#  '488299',
#  '565099',
#  '663899',
#  '414099',
#  '338199',
#  '459899',
#  '846599',
#  '330299',
#  '598299',
#  '471199',
#  '469099',
#  '565699',
#  '731899',
#  '438099',
#  '580699',
#  '900899',
#  '762199',
#  '437599',
#  '341699',
#  '386299',
#  '2268199',
#  '464899',
#  '504299',
#  '542799',
#  '1118899',
#  '1023099',
#  '562399',
#  '489599',
#  '574899',
#  '396299',
#  '494199',
#  '372999',
#  '560499',
#  '389899',
#  '425599',
#  '479699',
#  '686299',
#  '291599',
#  '446799',
#  '565099',
#  '2314599',
#  '598499',
#  '400399',
#  '324999',
#  '475499',
#  '970599',
#  '680699',
#  '292899',
#  '665599',
#  '491599',
#  '220299',
#  '688299',
#  '289799',
#  '889826',
#  '472099',
#  '704699',
#  '653199',
#  '445299',
#  '671099',
#  '1371399',
#  '424599',
#  '311499',
#  '1182299',
#  '1504999',
#  '367499',
#  '899099',
#  '467399',
#  '605699',
#  '493899',
#  '444399',
# ...

# %%
locationchange7=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange7
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange7.click()

# %%
ahmedabad=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/ul/li[10]')
ahmedabad
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="b741527d-4bb4-48ab-bcae-9e6f5af0a3c2")>

# %%
ahmedabad.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname7=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname7[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="834f1b9d-7d81-4c8a-a325-71e1eb8f5d2c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1477113b-c59c-49f9-8e21-733d88d0ad69")>]

# %%
carnames7=[]
for i in carname7:
    carnames7.append(i.text.split()[1:])
carnames7
# Out:
# [['Hyundai', 'Grand', 'i10'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Maruti', 'Alto', 'K10'],
#  ['Maruti', 'Ertiga'],
#  ['Maruti', 'Ertiga'],
#  ['Maruti', 'New', 'Wagon-R'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Mahindra', 'XUV500'],
#  ['Maruti', 'Swift'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Baleno'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Swift'],
#  ['Volkswagen', 'Polo'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Alto', '800'],
#  ['Mahindra', 'XUV500'],
#  ['Maruti', 'Swift'],
#  ['Toyota', 'Innova', 'Crysta'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Alto', '800'],
#  ['Maruti', 'Eeco'],
#  ['Renault', 'Kwid'],
#  ['Renault', 'Kwid'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Hyundai', 'GRAND', 'I10', 'NIOS'],
#  ['Hyundai', 'Verna'],
#  ['Maruti', 'S', 'PRESSO'],
#  ['Toyota', 'Etios', 'Liva'],
#  ['Mahindra', 'XUV500'],
#  ['Volkswagen', 'Polo'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Eeco'],
# ...

# %%
len(carnames7)
# Out:
# 391

# %%
year7=[]
for i in carname7:
    year7.append(i.text.split()[0])
year7
# Out:
# ['2017',
#  '2017',
#  '2016',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2021',
#  '2016',
#  '2019',
#  '2020',
#  '2017',
#  '2017',
#  '2018',
#  '2019',
#  '2018',
#  '2015',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2017',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2021',
#  '2020',
#  '2017',
#  '2013',
#  '2020',
#  '2016',
#  '2020',
#  '2018',
#  '2014',
#  '2021',
#  '2013',
#  '2015',
#  '2017',
#  '2019',
#  '2016',
#  '2020',
#  '2020',
#  '2022',
#  '2020',
#  '2015',
#  '2018',
#  '2017',
#  '2019',
#  '2021',
#  '2019',
#  '2017',
#  '2016',
#  '2017',
#  '2019',
#  '2015',
#  '2020',
#  '2014',
#  '2020',
#  '2019',
#  '2021',
#  '2016',
#  '2021',
#  '2018',
#  '2018',
#  '2014',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2016',
#  '2015',
#  '2017',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2017',
#  '2020',
# ...

# %%
model7=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model7[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="44e45537-5b4c-4761-9841-e8cff7457585")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="60f489be-6a4a-42c2-a315-dd2b121a4d15")>]

# %%
models7=[]
for i in model7:
    models7.append(i.text.replace('Automatic','').replace('Manual',''))
models7
# Out:
# ['MAGNA 1.2 KAPPA VTVT ',
#  'ASTA 1.2 (O) ',
#  'VXI ',
#  'ZXI Plus SHVS ',
#  'ZXI Plus SHVS ',
#  'VXI 1.0 ',
#  'LXI ',
#  'W7 FWD ',
#  'VXI ',
#  'COMFORTLINE PLUS 1.0 ',
#  'ZETA 1.2 K12 CVT ',
#  'HIGHLINE1.2L PETROL ',
#  'VXI ',
#  'GT TSI AT 1.0 ',
#  'RXT ',
#  'LXI ',
#  'W9 ',
#  'VXI ',
#  '2.4 GX 7 STR ',
#  'VXI ',
#  'LXI ',
#  '5 STR WITH AC PLUSHTR ',
#  '1.0 RXT Opt ',
#  '1.0 RXT Opt ',
#  '1.0 RXT Opt ',
#  'VXI ',
#  'SPORTZ PETROL ',
#  '1.6 SX VTVT ',
#  'VXI ',
#  'GD ',
#  'W9 ',
#  'COMFORTLINE 1.0 PETROL ',
#  'MAGNA 1.2 KAPPA VTVT ',
#  'HIGHLINE1.5L DIESEL ',
#  '5 STR WITH AC PLUSHTR ',
#  'S MT 1.2 KAPPA ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'VXI ',
#  'Neotech Petrol 1.0 ',
#  'SIGMA 1.2 K12 ',
#  'LXI ',
#  'VXI ',
#  'VXI ',
#  'LX PETROL AT 4WD ',
#  '2.5 VX 8 STR BS IV ',
#  'VXI ',
#  '5 STR WITH AC PLUSHTR ',
#  'DELTA 1.2 K12 ',
#  'ZDI PLUS DUAL TONE ',
#  'VXI PLUS ',
#  'VXI ',
#  'ZETA SHVS PETROL ',
#  'HTK PLUS 1.5 DIESEL ',
# ...

# %%
transmission7=[]
for i in model7:
    transmission7.append(i.text.split()[-1])
transmission7
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
# ...

# %%
detail7=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail7[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="b61ba082-5d9e-43f2-b11d-bc5adabe2389")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f2460ab4-654f-4c86-a2a1-05310d49224d")>]

# %%
details7=[]
for i in detail7:
    details7.append(i.text.replace('\n',' '))
details7
# Out:
# ['32,628 km 1st Owner Petrol',
#  '45,065 km 1st Owner Petrol',
#  '8,339 km 1st Owner Petrol',
#  '29,438 km 1st Owner Petrol',
#  '21,596 km 2nd Owner Petrol',
#  '3,586 km 1st Owner Petrol',
#  '4,646 km 1st Owner Petrol',
#  '57,552 km 1st Owner Diesel',
#  '25,343 km 2nd Owner Petrol',
#  '8,269 km 1st Owner Petrol',
#  '3,195 km 1st Owner Petrol',
#  '40,074 km 1st Owner Petrol',
#  '37,711 km 2nd Owner Petrol',
#  '8,476 km 2nd Owner Petrol',
#  '18,111 km 1st Owner Petrol',
#  '10,006 km 1st Owner Petrol',
#  '47,483 km 2nd Owner Diesel',
#  '46,384 km 2nd Owner Petrol',
#  '52,410 km 1st Owner Diesel',
#  '36,695 km 1st Owner Petrol',
#  '6,118 km 2nd Owner Petrol',
#  '11,247 km 1st Owner Petrol',
#  '31,436 km 1st Owner Petrol',
#  '30,814 km 1st Owner Petrol',
#  '16,721 km 1st Owner Petrol',
#  '6,580 km 1st Owner Petrol',
#  '19,817 km 1st Owner Petrol',
#  '5,788 km 2nd Owner Petrol',
#  '10,024 km 1st Owner Petrol',
#  '58,134 km 1st Owner Diesel',
# ...

# %%
driven7=[]
for i in detail7:
    driven7.append(i.text.split()[0].replace(',',''))
driven7
# Out:
# ['32628',
#  '45065',
#  '8339',
#  '29438',
#  '21596',
#  '3586',
#  '4646',
#  '57552',
#  '25343',
#  '8269',
#  '3195',
#  '40074',
#  '37711',
#  '8476',
#  '18111',
#  '10006',
#  '47483',
#  '46384',
#  '52410',
#  '36695',
#  '6118',
#  '11247',
#  '31436',
#  '30814',
#  '16721',
#  '6580',
#  '19817',
#  '5788',
#  '10024',
#  '58134',
#  '115157',
#  '26980',
#  '26929',
#  '68394',
#  '2340',
#  '5306',
#  '7807',
#  '71052',
#  '24963',
#  '26962',
#  '2966',
#  '38507',
#  '51748',
#  '950',
#  '281380',
#  '39435',
#  '39550',
#  '28632',
#  '49531',
#  '8452',
#  '19851',
#  '14122',
#  '52970',
#  '58962',
#  '31321',
#  '83464',
#  '8559',
#  '8543',
#  '36999',
#  '15740',
#  '48280',
#  '15568',
#  '18392',
#  '38635',
#  '10273',
#  '80441',
#  '6279',
#  '32030',
#  '12467',
#  '14642',
#  '5035',
#  '21445',
#  '40422',
#  '87194',
#  '24186',
#  '20605',
#  '84312',
#  '37768',
#  '9783',
#  '12164',
#  '43882',
#  '40054',
#  '36850',
#  '3521',
#  '9239',
# ...

# %%
owner7=[]
for i in detail7:
    owner7.append(i.text.split()[2])
owner7
# Out:
# ['1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
# ...

# %%
fueltype7=[]
for i in detail7:
    fueltype7.append(i.text.split()[4])
fueltype7
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
# ...

# %%
detail17=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail17[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="77dae04a-a609-4e61-9f55-b335d87ce123")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="9a43a62f-4f38-4001-b797-5dd47e635591")>]

# %%
details17=[]
for i in detail17:
    details17.append(i.text.replace('/month\n',' '))
details17
# Out:
# ['₹10,860 ₹4,88,199',
#  '₹15,702 ₹7,05,899',
#  '₹7,510 ₹3,37,599',
#  '₹23,114 ₹10,39,099',
#  '₹23,114 ₹10,39,099',
#  '₹12,915 ₹5,80,599',
#  '₹18,229 ₹8,19,499',
#  '₹25,154 ₹11,30,799',
#  '₹11,965 ₹5,37,899',
#  '₹16,078 ₹7,22,799',
#  '₹23,259 ₹10,45,599',
#  '₹12,528 ₹5,63,199',
#  '₹12,541 ₹5,63,799',
#  '₹21,744 ₹9,77,499',
#  '₹7,196 ₹3,23,499',
#  '₹6,942 ₹3,12,099',
#  '₹24,914 ₹11,19,999',
#  '₹12,541 ₹5,63,799',
#  '₹33,093 ₹14,87,699',
#  '₹10,826 ₹4,86,699',
#  '₹7,490 ₹3,36,699',
#  '₹11,009 ₹4,94,899',
#  '₹8,024 ₹3,60,699',
#  '₹7,712 ₹3,46,699',
#  '₹8,493 ₹3,81,799',
#  '₹19,568 ₹8,79,699',
#  '₹15,269 ₹6,86,399',
#  '₹22,093 ₹9,93,199',
#  '₹10,415 ₹4,68,199',
#  '₹10,655 ₹4,78,999',
#  '₹24,273 ₹10,91,199',
#  '₹12,926 ₹5,81,099',
#  '₹10,588 ₹4,75,999',
#  '₹12,995 ₹5,84,199',
#  '₹11,821 ₹5,31,399',
#  '₹17,893 ₹8,04,399',
#  '₹11,636 ₹5,23,099',
#  '₹9,082 ₹4,08,299',
#  '₹10,188 ₹4,57,999',
#  '₹11,438 ₹5,14,199',
#  '₹8,535 ₹3,83,699',
# ...

# %%
downpayment7=[]
for i in detail17:
    downpayment7.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment7
# Out:
# ['10860',
#  '15702',
#  '7510',
#  '23114',
#  '23114',
#  '12915',
#  '18229',
#  '25154',
#  '11965',
#  '16078',
#  '23259',
#  '12528',
#  '12541',
#  '21744',
#  '7196',
#  '6942',
#  '24914',
#  '12541',
#  '33093',
#  '10826',
#  '7490',
#  '11009',
#  '8024',
#  '7712',
#  '8493',
#  '19568',
#  '15269',
#  '22093',
#  '10415',
#  '10655',
#  '24273',
#  '12926',
#  '10588',
#  '12995',
#  '11821',
#  '17893',
#  '11636',
#  '9082',
#  '10188',
#  '11438',
#  '8535',
#  '10926',
#  '9814',
#  '36281',
#  '15573',
#  '11487',
#  '9830',
#  '13493',
#  '15762',
#  '10773',
#  '15974',
#  '25675',
#  '30099',
#  '8515',
#  '10953',
#  '11489',
#  '16850',
#  '14606',
#  '24636',
#  '6749',
#  '14203',
#  '9716',
#  '20985',
#  '8177',
#  '8609',
#  '10453',
#  '14345',
#  '10760',
#  '24524',
#  '9534',
#  '11821',
#  '14784',
#  '43781',
#  '13360',
#  '21212',
#  '12553',
#  '30924',
#  '14092',
#  '9396',
#  '13765',
#  '15564',
#  '12148',
#  '6571',
#  '13723',
# ...

# %%
price7=[]
for i in detail17:
    price7.append(i.text.split()[-1].replace('₹','').replace(',',''))
price7
# Out:
# ['488199',
#  '705899',
#  '337599',
#  '1039099',
#  '1039099',
#  '580599',
#  '819499',
#  '1130799',
#  '537899',
#  '722799',
#  '1045599',
#  '563199',
#  '563799',
#  '977499',
#  '323499',
#  '312099',
#  '1119999',
#  '563799',
#  '1487699',
#  '486699',
#  '336699',
#  '494899',
#  '360699',
#  '346699',
#  '381799',
#  '879699',
#  '686399',
#  '993199',
#  '468199',
#  '478999',
#  '1091199',
#  '581099',
#  '475999',
#  '584199',
#  '531399',
#  '804399',
#  '523099',
#  '408299',
#  '457999',
#  '514199',
#  '383699',
#  '491199',
#  '441199',
#  '1630999',
#  '700099',
#  '516399',
#  '441899',
#  '606599',
#  '708599',
#  '484299',
#  '718099',
#  '1154199',
#  '1353099',
#  '382799',
#  '492399',
#  '516499',
#  '757499',
#  '656599',
#  '1107499',
#  '303399',
#  '638499',
#  '436799',
#  '943399',
#  '367599',
#  '386999',
#  '469899',
#  '644899',
#  '483699',
#  '1102499',
#  '428599',
#  '531399',
#  '664599',
#  '1968199',
#  '600599',
#  '953599',
# ...

# %%
locationchange8=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange8
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange8.click()

# %%
vadodara=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div/div/ul/div[19]/li[1]/a/span')
vadodara
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="200349a6-158a-4572-8a34-bf952f44bf67")>

# %%
vadodara.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname8=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname8[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="a037c579-a56a-488a-94ae-316cae4861a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="47fe0a76-903f-48fc-a66c-0c4f4711dfe1")>]

# %%
carnames8=[]
for i in carname8:
    carnames8.append(i.text.split()[1:])
carnames8
# Out:
# [['Maruti', 'Alto', 'K10'],
#  ['Maruti', 'Ertiga'],
#  ['Maruti', 'Ertiga'],
#  ['Maruti', 'New', 'Wagon-R'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Mahindra', 'XUV500'],
#  ['Maruti', 'Swift'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Baleno'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Swift'],
#  ['Volkswagen', 'Polo'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Alto', '800'],
#  ['Mahindra', 'XUV500'],
#  ['Maruti', 'Swift'],
#  ['Toyota', 'Innova', 'Crysta'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Alto', '800'],
#  ['Maruti', 'Eeco'],
#  ['Renault', 'Kwid'],
#  ['Renault', 'Kwid'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Hyundai', 'GRAND', 'I10', 'NIOS'],
#  ['Hyundai', 'Verna'],
#  ['Maruti', 'S', 'PRESSO'],
#  ['Toyota', 'Etios', 'Liva'],
#  ['Mahindra', 'XUV500'],
#  ['Volkswagen', 'Polo'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Volkswagen', 'Polo'],
#  ['Maruti', 'Eeco'],
#  ['Hyundai', 'VENUE'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Maruti', 'Swift'],
# ...

# %%
len(carnames8)
# Out:
# 391

# %%
year8=[]
for i in carname8:
    year8.append(i.text.split()[0])
year8
# Out:
# ['2016',
#  '2020',
#  '2020',
#  '2020',
#  '2021',
#  '2019',
#  '2018',
#  '2020',
#  '2021',
#  '2016',
#  '2019',
#  '2020',
#  '2017',
#  '2017',
#  '2018',
#  '2019',
#  '2018',
#  '2015',
#  '2018',
#  '2020',
#  '2018',
#  '2018',
#  '2018',
#  '2021',
#  '2020',
#  '2019',
#  '2020',
#  '2017',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2021',
#  '2020',
#  '2017',
#  '2013',
#  '2020',
#  '2016',
#  '2020',
#  '2018',
#  '2014',
#  '2021',
#  '2013',
#  '2015',
#  '2017',
#  '2019',
#  '2016',
#  '2020',
#  '2020',
#  '2022',
#  '2020',
#  '2015',
#  '2018',
#  '2017',
#  '2019',
#  '2021',
#  '2019',
#  '2017',
#  '2016',
#  '2017',
#  '2019',
#  '2015',
#  '2020',
#  '2014',
#  '2020',
#  '2019',
#  '2021',
#  '2016',
#  '2021',
#  '2018',
#  '2018',
#  '2014',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2016',
#  '2015',
#  '2017',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2017',
#  '2020',
#  '2018',
#  '2017',
# ...

# %%
model8=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model8[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="6b74caad-12f0-4afe-90ee-a82ed191dea6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="69c8e730-b37c-4923-9c26-441f22b9915d")>]

# %%
models8=[]
for i in model8:
    models8.append(i.text.replace('Automatic','').replace('Manual',''))
models8
# Out:
# ['VXI ',
#  'ZXI Plus SHVS ',
#  'ZXI Plus SHVS ',
#  'VXI 1.0 ',
#  'LXI ',
#  'W7 FWD ',
#  'VXI ',
#  'COMFORTLINE PLUS 1.0 ',
#  'ZETA 1.2 K12 CVT ',
#  'HIGHLINE1.2L PETROL ',
#  'VXI ',
#  'GT TSI AT 1.0 ',
#  'RXT ',
#  'LXI ',
#  'W9 ',
#  'VXI ',
#  '2.4 GX 7 STR ',
#  'VXI ',
#  'LXI ',
#  '5 STR WITH AC PLUSHTR ',
#  '1.0 RXT Opt ',
#  '1.0 RXT Opt ',
#  '1.0 RXT Opt ',
#  'VXI ',
#  'SPORTZ PETROL ',
#  '1.6 SX VTVT ',
#  'VXI ',
#  'GD ',
#  'W9 ',
#  'COMFORTLINE 1.0 PETROL ',
#  'MAGNA 1.2 KAPPA VTVT ',
#  'HIGHLINE1.5L DIESEL ',
#  '5 STR WITH AC PLUSHTR ',
#  'S MT 1.2 KAPPA ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'VXI ',
#  'Neotech Petrol 1.0 ',
#  'SIGMA 1.2 K12 ',
#  'LXI ',
#  'VXI ',
#  'VXI ',
#  'LX PETROL AT 4WD ',
#  '2.5 VX 8 STR BS IV ',
#  'VXI ',
#  '5 STR WITH AC PLUSHTR ',
#  'DELTA 1.2 K12 ',
#  'ZDI PLUS DUAL TONE ',
#  'VXI PLUS ',
#  'VXI ',
#  'ZETA SHVS PETROL ',
#  'HTK PLUS 1.5 DIESEL ',
#  'SPORTZ 1.1 IRDE2 ',
#  'VXI ',
#  'DELTA DDIS 190 ',
# ...

# %%
transmission8=[]
for i in model8:
    transmission8.append(i.text.split()[-1])
transmission8
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
# ...

# %%
detail8=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail8[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="4c734829-21d1-4146-b3c2-b784ca32a531")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="bd9c9df9-3af5-45c6-8def-40c359954c58")>]

# %%
details8=[]
for i in detail8:
    details8.append(i.text.replace('\n',' '))
details8
# Out:
# ['8,339 km 1st Owner Petrol',
#  '29,438 km 1st Owner Petrol',
#  '21,596 km 2nd Owner Petrol',
#  '3,586 km 1st Owner Petrol',
#  '4,646 km 1st Owner Petrol',
#  '57,552 km 1st Owner Diesel',
#  '25,343 km 2nd Owner Petrol',
#  '8,269 km 1st Owner Petrol',
#  '3,195 km 1st Owner Petrol',
#  '40,074 km 1st Owner Petrol',
#  '37,711 km 2nd Owner Petrol',
#  '8,476 km 2nd Owner Petrol',
#  '18,111 km 1st Owner Petrol',
#  '10,006 km 1st Owner Petrol',
#  '47,483 km 2nd Owner Diesel',
#  '46,384 km 2nd Owner Petrol',
#  '52,410 km 1st Owner Diesel',
#  '36,695 km 1st Owner Petrol',
#  '6,118 km 2nd Owner Petrol',
#  '11,247 km 1st Owner Petrol',
#  '31,436 km 1st Owner Petrol',
#  '30,814 km 1st Owner Petrol',
#  '16,721 km 1st Owner Petrol',
#  '6,580 km 1st Owner Petrol',
#  '19,817 km 1st Owner Petrol',
#  '5,788 km 2nd Owner Petrol',
#  '10,024 km 1st Owner Petrol',
#  '58,134 km 1st Owner Diesel',
#  '1,15,157 km 1st Owner Diesel',
#  '26,980 km 1st Owner Petrol',
# ...

# %%
driven8=[]
for i in detail8:
    driven8.append(i.text.split()[0].replace(',',''))
driven8
# Out:
# ['8339',
#  '29438',
#  '21596',
#  '3586',
#  '4646',
#  '57552',
#  '25343',
#  '8269',
#  '3195',
#  '40074',
#  '37711',
#  '8476',
#  '18111',
#  '10006',
#  '47483',
#  '46384',
#  '52410',
#  '36695',
#  '6118',
#  '11247',
#  '31436',
#  '30814',
#  '16721',
#  '6580',
#  '19817',
#  '5788',
#  '10024',
#  '58134',
#  '115157',
#  '26980',
#  '26929',
#  '68394',
#  '2340',
#  '5306',
#  '7807',
#  '71052',
#  '24963',
#  '26962',
#  '2966',
#  '38507',
#  '51748',
#  '950',
#  '281380',
#  '39435',
#  '39550',
#  '28632',
#  '49531',
#  '8452',
#  '19851',
#  '14122',
#  '52970',
#  '58962',
#  '31321',
#  '83464',
#  '8559',
#  '8543',
#  '36999',
#  '15740',
#  '48280',
#  '15568',
#  '18392',
#  '38635',
#  '10273',
#  '80441',
#  '6279',
#  '32030',
#  '12467',
#  '14642',
#  '5035',
#  '21445',
#  '40422',
#  '87194',
#  '24186',
#  '20605',
#  '84312',
#  '37768',
#  '9783',
#  '12164',
#  '43882',
#  '40054',
#  '36850',
#  '3521',
#  '9239',
#  '37237',
#  '3929',
# ...

# %%
owner8=[]
for i in detail8:
    owner8.append(i.text.split()[2])
owner8
# Out:
# ['1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
# ...

# %%
fueltype8=[]
for i in detail8:
    fueltype8.append(i.text.split()[4])
fueltype8
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
# ...

# %%
detail18=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail18[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f7ffbec9-3cca-47bf-b226-092070ad7c4f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="08202897-9fff-42f5-a72b-c8b6ceed1cfa")>]

# %%
details18=[]
for i in detail18:
    details18.append(i.text.replace('/month\n',' '))
details18
# Out:
# ['₹7,510 ₹3,37,599',
#  '₹23,114 ₹10,39,099',
#  '₹23,114 ₹10,39,099',
#  '₹12,915 ₹5,80,599',
#  '₹18,229 ₹8,19,499',
#  '₹25,154 ₹11,30,799',
#  '₹11,965 ₹5,37,899',
#  '₹16,078 ₹7,22,799',
#  '₹23,259 ₹10,45,599',
#  '₹12,528 ₹5,63,199',
#  '₹12,541 ₹5,63,799',
#  '₹21,744 ₹9,77,499',
#  '₹7,196 ₹3,23,499',
#  '₹6,942 ₹3,12,099',
#  '₹24,914 ₹11,19,999',
#  '₹12,541 ₹5,63,799',
#  '₹33,093 ₹14,87,699',
#  '₹10,826 ₹4,86,699',
#  '₹7,490 ₹3,36,699',
#  '₹11,009 ₹4,94,899',
#  '₹8,024 ₹3,60,699',
#  '₹7,712 ₹3,46,699',
#  '₹8,493 ₹3,81,799',
#  '₹19,568 ₹8,79,699',
#  '₹15,269 ₹6,86,399',
#  '₹22,093 ₹9,93,199',
#  '₹10,415 ₹4,68,199',
#  '₹10,655 ₹4,78,999',
#  '₹24,273 ₹10,91,199',
#  '₹12,926 ₹5,81,099',
#  '₹10,588 ₹4,75,999',
#  '₹12,995 ₹5,84,199',
#  '₹11,821 ₹5,31,399',
#  '₹17,893 ₹8,04,399',
#  '₹11,636 ₹5,23,099',
#  '₹9,082 ₹4,08,299',
#  '₹10,188 ₹4,57,999',
#  '₹11,438 ₹5,14,199',
#  '₹8,535 ₹3,83,699',
#  '₹10,926 ₹4,91,199',
#  '₹9,814 ₹4,41,199',
# ...

# %%
downpayment8=[]
for i in detail18:
    downpayment8.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment8
# Out:
# ['7510',
#  '23114',
#  '23114',
#  '12915',
#  '18229',
#  '25154',
#  '11965',
#  '16078',
#  '23259',
#  '12528',
#  '12541',
#  '21744',
#  '7196',
#  '6942',
#  '24914',
#  '12541',
#  '33093',
#  '10826',
#  '7490',
#  '11009',
#  '8024',
#  '7712',
#  '8493',
#  '19568',
#  '15269',
#  '22093',
#  '10415',
#  '10655',
#  '24273',
#  '12926',
#  '10588',
#  '12995',
#  '11821',
#  '17893',
#  '11636',
#  '9082',
#  '10188',
#  '11438',
#  '8535',
#  '10926',
#  '9814',
#  '36281',
#  '15573',
#  '11487',
#  '9830',
#  '13493',
#  '15762',
#  '10773',
#  '15974',
#  '25675',
#  '30099',
#  '8515',
#  '10953',
#  '11489',
#  '16850',
#  '14606',
#  '24636',
#  '6749',
#  '14203',
#  '9716',
#  '20985',
#  '8177',
#  '8609',
#  '10453',
#  '14345',
#  '10760',
#  '24524',
#  '9534',
#  '11821',
#  '14784',
#  '43781',
#  '13360',
#  '21212',
#  '12553',
#  '30924',
#  '14092',
#  '9396',
#  '13765',
#  '15564',
#  '12148',
#  '6571',
#  '13723',
#  '11360',
#  '29498',
#  '7674',
# ...

# %%
price8=[]
for i in detail18:
    price8.append(i.text.split()[-1].replace('₹','').replace(',',''))
price8
# Out:
# ['337599',
#  '1039099',
#  '1039099',
#  '580599',
#  '819499',
#  '1130799',
#  '537899',
#  '722799',
#  '1045599',
#  '563199',
#  '563799',
#  '977499',
#  '323499',
#  '312099',
#  '1119999',
#  '563799',
#  '1487699',
#  '486699',
#  '336699',
#  '494899',
#  '360699',
#  '346699',
#  '381799',
#  '879699',
#  '686399',
#  '993199',
#  '468199',
#  '478999',
#  '1091199',
#  '581099',
#  '475999',
#  '584199',
#  '531399',
#  '804399',
#  '523099',
#  '408299',
#  '457999',
#  '514199',
#  '383699',
#  '491199',
#  '441199',
#  '1630999',
#  '700099',
#  '516399',
#  '441899',
#  '606599',
#  '708599',
#  '484299',
#  '718099',
#  '1154199',
#  '1353099',
#  '382799',
#  '492399',
#  '516499',
#  '757499',
#  '656599',
#  '1107499',
#  '303399',
#  '638499',
#  '436799',
#  '943399',
#  '367599',
#  '386999',
#  '469899',
#  '644899',
#  '483699',
#  '1102499',
#  '428599',
#  '531399',
#  '664599',
#  '1968199',
#  '600599',
#  '953599',
#  '564299',
#  '1390199',
# ...

# %%
locationchange9=driver.find_element_by_xpath('/html/body/div[1]/div[1]/header/div/div[1]/div[2]/p')
locationchange9
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="1eb71884-32af-43b8-b30b-ca1f3db3a676")>

# %%
locationchange9.click()

# %%
faridabad=driver.find_element_by_xpath('/html/body/div[1]/div[6]/div/div/div/div[2]/div/div/ul/div[5]/li/a/span')
faridabad
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="ce51a73d-8db4-4ddb-81f5-a9fa452cbd56")>

# %%
faridabad.click()

# %%
driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')

# %%
carname9=driver.find_elements_by_xpath('//h2[@class="_3FpCg"]')
carname9[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="e40a2fe7-db04-4c9a-a7fa-877bf9f52712")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f715580b-c7ad-4485-8ba8-1379f1384230")>]

# %%
carnames9=[]
for i in carname9:
    carnames9.append(i.text.split()[1:])
carnames9
# Out:
# [['Maruti', 'Swift', 'Dzire'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Toyota', 'Corolla', 'Altis'],
#  ['Ford', 'Ecosport'],
#  ['Maruti', 'Baleno'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Baleno'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Mahindra', 'Scorpio'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Toyota', 'Fortuner'],
#  ['Hyundai', 'i20'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Swift'],
#  ['Renault', 'Duster'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Swift'],
#  ['Maruti', 'Vitara', 'Brezza'],
#  ['Maruti', 'Swift'],
#  ['Hyundai', 'Verna'],
#  ['Maruti', 'Alto', '800'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Maruti', 'Alto', 'K10'],
#  ['MG', 'HECTOR'],
#  ['Maruti', 'Alto', 'K10'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['MG', 'HECTOR'],
#  ['Maruti', 'Ertiga'],
#  ['Hyundai', 'NEW', 'SANTRO'],
#  ['Jeep', 'Compass'],
#  ['Hyundai', 'VENUE'],
#  ['Maruti', 'Swift'],
#  ['MG', 'HECTOR'],
# ...

# %%
len(carnames9)
# Out:
# 684

# %%
year9=[]
for i in carname9:
    year9.append(i.text.split()[0])
year9
# Out:
# ['2015',
#  '2016',
#  '2014',
#  '2017',
#  '2020',
#  '2016',
#  '2017',
#  '2017',
#  '2016',
#  '2017',
#  '2013',
#  '2013',
#  '2016',
#  '2017',
#  '2016',
#  '2015',
#  '2017',
#  '2014',
#  '2013',
#  '2019',
#  '2019',
#  '2019',
#  '2013',
#  '2014',
#  '2011',
#  '2019',
#  '2011',
#  '2010',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2021',
#  '2017',
#  '2019',
#  '2017',
#  '2009',
#  '2019',
#  '2010',
#  '2017',
#  '2014',
#  '2011',
#  '2019',
#  '2016',
#  '2016',
#  '2015',
#  '2014',
#  '2014',
#  '2020',
#  '2017',
#  '2017',
#  '2021',
#  '2013',
#  '2013',
#  '2019',
#  '2019',
#  '2017',
#  '2018',
#  '2018',
#  '2014',
#  '2017',
#  '2017',
#  '2011',
#  '2018',
#  '2016',
#  '2017',
#  '2016',
#  '2019',
#  '2015',
#  '2019',
#  '2019',
#  '2017',
#  '2011',
#  '2014',
#  '2020',
#  '2019',
#  '2014',
#  '2018',
#  '2017',
#  '2019',
#  '2018',
#  '2019',
#  '2017',
#  '2018',
#  '2021',
#  '2011',
#  '2015',
#  '2020',
#  '2015',
#  '2021',
# ...

# %%
model9=driver.find_elements_by_xpath('//p[@class="cvakB"]')
model9[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="d6f3df34-501e-4c2d-9802-6d79dd6cfb99")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="7ac760cf-2ec0-44a8-bc86-8733cf538197")>]

# %%
models9=[]
for i in model9:
    models9.append(i.text.replace('Automatic','').replace('Manual',''))
models9
# Out:
# ['VDI ABS ',
#  'VDI ',
#  'D 4D J ',
#  '1.5TITANIUM TDCI ',
#  'DELTA 1.2 K12 ',
#  'VDI ',
#  'DELTA 1.2 K12 ',
#  'VDI ',
#  'S10 ',
#  'MAGNA 1.2 VTVT ',
#  '3.0 AT 4X2 ',
#  'ERA 1.4 CRDI ',
#  'VDI ',
#  'SPORTZ 1.2 KAPPA VTVT ',
#  'ZDI PLUS ',
#  'VDI ABS ',
#  'RXZ DIESEL 110 ',
#  'VDI ',
#  'VDI ',
#  'VDI ',
#  'VXI ',
#  '1.6 SX VTVT (O) ',
#  'LXI ',
#  'LXI ',
#  'VXI ',
#  'SUPER DIESEL ',
#  'VXI ',
#  'LXI ',
#  'SHARP 2.0 DIESEL ',
#  'ZXI SMART HYBRID ',
#  'ERA 1.1 ',
#  '2.0 LIMITED ',
#  'S MT 1.2 KAPPA ',
#  'LXI ',
#  'SHARP DCT PETROL ',
#  'GL ',
#  'ERA 1.1 IRDE ',
#  'V MT PETROL ',
#  'S MT PETROL ',
#  'VXI ',
#  'MAGNA 1.1 IRDE2 ',
#  'LXI ',
#  'SHARP DCT PETROL ',
#  'SV MT PETROL ',
#  'ZDI+ SHVS ',
#  'COMFORTLINE 1.2L PETROL ',
#  'VXI ',
#  'VX MT PETROL ',
#  'ZXI+ ',
#  'ZETA 1.2 K12 ',
#  'VDI+ SHVS ',
#  'XZ 2.0L Kryotec ',
#  'VDI ABS ',
#  'LXI ',
#  'XT 1.2 REVOTRON ',
#  'MAGNA 1.2 VTVT ',
#  '2.0 SPORT ',
#  'VXI ',
#  'RXL ',
# ...

# %%
transmission9=[]
for i in model9:
    transmission9.append(i.text.split()[-1])
transmission9
# Out:
# ['Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
# ...

# %%
detail9=driver.find_elements_by_xpath('//ul[@class="bVR0c"]')
detail9[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="f7835499-ddf2-4b83-95d5-cc42dd234673")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="fceb2f9a-f8c0-41fa-a1f1-66dd1be37cf6")>]

# %%
details9=[]
for i in detail9:
    details9.append(i.text.replace('\n',' '))
details9
# Out:
# ['76,094 km 1st Owner Diesel',
#  '38,144 km 1st Owner Diesel',
#  '1,05,711 km 1st Owner Diesel',
#  '80,755 km 1st Owner Diesel',
#  '29,252 km 2nd Owner Petrol',
#  '36,693 km 1st Owner Diesel',
#  '64,101 km 1st Owner Petrol',
#  '47,655 km 1st Owner Diesel',
#  '87,758 km 2nd Owner Diesel',
#  '49,130 km 1st Owner Petrol',
#  '1,97,865 km 1st Owner Diesel',
#  '32,925 km 1st Owner Diesel',
#  '66,181 km 2nd Owner Diesel',
#  '37,117 km 1st Owner Petrol',
#  '37,191 km 1st Owner Diesel',
#  '83,576 km 1st Owner Diesel',
#  '68,107 km 1st Owner Diesel',
#  '39,381 km 1st Owner Diesel',
#  '68,431 km 1st Owner Diesel',
#  '20,960 km 1st Owner Diesel',
#  '32,251 km 1st Owner Petrol',
#  '80,631 km 1st Owner Petrol',
#  '12,849 km 2nd Owner Petrol',
#  '26,866 km 1st Owner Petrol',
#  '37,580 km 1st Owner Petrol',
#  '52,447 km 2nd Owner Diesel',
#  '26,475 km 1st Owner Petrol',
#  '48,915 km 2nd Owner Petrol',
#  '49,413 km 1st Owner Diesel',
#  '61,780 km 1st Owner Petrol',
# ...

# %%
driven9=[]
for i in detail9:
    driven9.append(i.text.split()[0].replace(',',''))
driven9
# Out:
# ['76094',
#  '38144',
#  '105711',
#  '80755',
#  '29252',
#  '36693',
#  '64101',
#  '47655',
#  '87758',
#  '49130',
#  '197865',
#  '32925',
#  '66181',
#  '37117',
#  '37191',
#  '83576',
#  '68107',
#  '39381',
#  '68431',
#  '20960',
#  '32251',
#  '80631',
#  '12849',
#  '26866',
#  '37580',
#  '52447',
#  '26475',
#  '48915',
#  '49413',
#  '61780',
#  '11358',
#  '46400',
#  '21490',
#  '32600',
#  '12267',
#  '58639',
#  '44319',
#  '41091',
#  '34566',
#  '30375',
#  '12511',
#  '23874',
#  '38644',
#  '45246',
#  '39585',
#  '51495',
#  '29335',
#  '54517',
#  '13357',
#  '35452',
#  '59411',
#  '10141',
#  '49273',
#  '99646',
#  '17858',
#  '16327',
#  '62443',
#  '12225',
#  '22505',
#  '27928',
#  '49358',
#  '30697',
#  '50581',
#  '13278',
#  '78295',
#  '76959',
#  '75956',
#  '43352',
#  '77157',
#  '2406',
#  '5633',
#  '46437',
#  '67923',
#  '31263',
#  '2775',
#  '22638',
#  '30537',
#  '30545',
#  '43277',
#  '38083',
#  '39475',
#  '25758',
#  '72728',
# ...

# %%
owner9=[]
for i in detail9:
    owner9.append(i.text.split()[2])
owner9
# Out:
# ['1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '3rd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
# ...

# %%
fueltype9=[]
for i in detail9:
    fueltype9.append(i.text.split()[4])
fueltype9
# Out:
# ['Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
# ...

# %%
detail19=driver.find_elements_by_xpath('//div[@class="_19zc5"]')
detail19[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="c0d3bc13-6d5a-4080-92b1-99f4e793f930")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="2096d2085ef3211a39ae643626719fed", element="7fd1b2f3-fd40-4502-a7ac-7825bffb5b27")>]

# %%
details19=[]
for i in detail19:
    details19.append(i.text.replace('/month\n',' '))
details19
# Out:
# ['₹10,159 ₹4,56,699',
#  '₹15,362 ₹6,90,599',
#  '₹14,274 ₹6,41,699',
#  '₹14,103 ₹6,33,999',
#  '₹14,450 ₹6,49,599',
#  '₹15,135 ₹6,80,399',
#  '₹11,934 ₹5,36,499',
#  '₹16,332 ₹7,34,199',
#  '₹22,736 ₹10,22,099',
#  '₹9,957 ₹4,47,599',
#  '₹25,586 ₹11,50,199',
#  '₹7,287 ₹3,27,599',
#  '₹13,901 ₹6,24,899',
#  '₹10,571 ₹4,75,199',
#  '₹15,484 ₹6,96,099',
#  '₹9,939 ₹4,46,799',
#  '₹15,175 ₹6,82,199',
#  '₹8,693 ₹3,90,799',
#  '₹7,236 ₹3,25,299',
#  '₹17,749 ₹7,97,899',
#  '₹12,466 ₹5,60,399',
#  '₹21,837 ₹9,81,699',
#  '₹5,695 ₹2,55,999',
#  '₹7,832 ₹3,52,099',
#  '₹5,339 ₹2,39,999',
#  '₹35,887 ₹16,13,299',
#  '₹5,239 ₹2,35,499',
#  '₹5,430 ₹2,44,099',
#  '₹34,984 ₹15,72,699',
#  '₹19,840 ₹8,91,899',
#  '₹9,765 ₹4,38,999',
#  '₹44,934 ₹20,19,999',
#  '₹18,272 ₹8,21,399',
#  '₹10,337 ₹4,64,699',
#  '₹39,466 ₹17,74,199',
#  '₹28,355 ₹12,74,699',
#  '₹4,542 ₹2,04,199',
#  '₹20,182 ₹9,07,299',
#  '₹9,429 ₹4,23,899',
#  '₹8,455 ₹3,80,099',
#  '₹7,574 ₹3,40,499',
#  '₹6,989 ₹3,14,199',
# ...

# %%
downpayment9=[]
for i in detail19:
    downpayment9.append(i.text.split()[0].replace('/month','').replace('₹','').replace(',',''))
downpayment9
# Out:
# ['10159',
#  '15362',
#  '14274',
#  '14103',
#  '14450',
#  '15135',
#  '11934',
#  '16332',
#  '22736',
#  '9957',
#  '25586',
#  '7287',
#  '13901',
#  '10571',
#  '15484',
#  '9939',
#  '15175',
#  '8693',
#  '7236',
#  '17749',
#  '12466',
#  '21837',
#  '5695',
#  '7832',
#  '5339',
#  '35887',
#  '5239',
#  '5430',
#  '34984',
#  '19840',
#  '9765',
#  '44934',
#  '18272',
#  '10337',
#  '39466',
#  '28355',
#  '4542',
#  '20182',
#  '9429',
#  '8455',
#  '7574',
#  '6989',
#  '38427',
#  '14781',
#  '14828',
#  '9790',
#  '9231',
#  '14448',
#  '17442',
#  '11200',
#  '14514',
#  '47054',
#  '11765',
#  '7472',
#  '10397',
#  '11371',
#  '21630',
#  '10866',
#  '7174',
#  '9812',
#  '22794',
#  '11629',
#  '8068',
#  '19386',
#  '36532',
#  '27572',
#  '13460',
#  '11554',
#  '45481',
#  '8388',
#  '9138',
#  '42211',
#  '10432',
#  '9176',
#  '40883',
#  '13745',
#  '12019',
#  '14888',
#  '8920',
#  '8858',
#  '10166',
#  '37680',
#  '14241',
#  '13627',
#  '11247',
# ...

# %%
price9=[]
for i in detail19:
    price9.append(i.text.split()[-1].replace('₹','').replace(',',''))
price9
# Out:
# ['456699',
#  '690599',
#  '641699',
#  '633999',
#  '649599',
#  '680399',
#  '536499',
#  '734199',
#  '1022099',
#  '447599',
#  '1150199',
#  '327599',
#  '624899',
#  '475199',
#  '696099',
#  '446799',
#  '682199',
#  '390799',
#  '325299',
#  '797899',
#  '560399',
#  '981699',
#  '255999',
#  '352099',
#  '239999',
#  '1613299',
#  '235499',
#  '244099',
#  '1572699',
#  '891899',
#  '438999',
#  '2019999',
#  '821399',
#  '464699',
#  '1774199',
#  '1274699',
#  '204199',
#  '907299',
#  '423899',
#  '380099',
#  '340499',
#  '314199',
#  '1727499',
#  '664499',
#  '666599',
#  '440099',
#  '414999',
#  '649499',
#  '784099',
#  '503499',
#  '652499',
#  '2115299',
#  '528899',
#  '335899',
#  '467399',
#  '511199',
#  '972399',
#  '488499',
#  '322499',
#  '441099',
#  '1024699',
#  '522799',
#  '362699',
#  '871499',
#  '1642299',
#  '1239499',
#  '605099',
#  '519399',
#  '2044599',
#  '377099',
#  '410799',
#  '1897599',
#  '468959',
#  '412499',
#  '1837899',
# ...

# %%
year10=year+year1+year2+year3+year4+year5+year6+year7+year8+year9
year10
# Out:
# ['2019',
#  '2020',
#  '2020',
#  '2018',
#  '2013',
#  '2020',
#  '2013',
#  '2009',
#  '2014',
#  '2019',
#  '2015',
#  '2019',
#  '2021',
#  '2020',
#  '2018',
#  '2019',
#  '2014',
#  '2016',
#  '2014',
#  '2021',
#  '2018',
#  '2019',
#  '2011',
#  '2021',
#  '2021',
#  '2020',
#  '2010',
#  '2015',
#  '2011',
#  '2010',
#  '2020',
#  '2020',
#  '2010',
#  '2013',
#  '2014',
#  '2021',
#  '2019',
#  '2021',
#  '2021',
#  '2011',
#  '2010',
#  '2021',
#  '2021',
#  '2013',
#  '2015',
#  '2021',
#  '2019',
#  '2017',
#  '2017',
#  '2016',
#  '2019',
#  '2021',
#  '2020',
#  '2014',
#  '2018',
#  '2021',
#  '2017',
#  '2014',
#  '2019',
#  '2019',
#  '2011',
#  '2017',
#  '2021',
#  '2020',
#  '2018',
#  '2017',
#  '2018',
#  '2018',
#  '2015',
#  '2018',
#  '2019',
#  '2018',
#  '2021',
#  '2017',
#  '2018',
#  '2018',
#  '2017',
#  '2015',
#  '2018',
#  '2019',
#  '2019',
#  '2016',
#  '2020',
#  '2016',
#  '2016',
#  '2020',
#  '2019',
#  '2018',
#  '2014',
#  '2014',
# ...

# %%
len(year10)
# Out:
# 5575

# %%
model10=models+models1+models2+models3+models4+models5+models6+models7+models8+models9
model10
# Out:
# ['1.6 SX VTVT (O) ',
#  'HTK PLUS 1.5 PETROL ',
#  'HTX AT PETROL ',
#  'SIGMA 1.2 K12 ',
#  'LXI ',
#  'ACTIVE 1.0 TSI ',
#  '2.2 DIESEL ',
#  'ERA 1.1 IRDE ',
#  'LXI ',
#  'VXI ',
#  'COMFORTLINE 1.2L PETROL ',
#  '2.0 LIMITED ',
#  'S MT 1.2 KAPPA ',
#  'SHARP HYBRID PETROL ',
#  'RXL ',
#  '1.2 MAGNA PLUS VTVT ',
#  'XE DIESEL ',
#  'SV MT PETROL ',
#  'MAGNA 1.1 IRDE2 ',
#  'RXT 1.0 AMT ',
#  'DELTA 1.2 K12 ',
#  'MAGNA 1.2 VTVT ',
#  'VXI ',
#  'ALPHA 1.5 MT VTVT SHVS ',
#  '1.5 SX CRDI MT ',
#  'RXL ',
#  'LXI ',
#  '3.0 AT 4X2 ',
#  'SPORTZ 1.2 KAPPA2 ',
#  'MAGNA O 1.2 ',
#  'MAGNA 1.2 VTVT ',
#  'VX MT PETROL ',
#  'S MT PETROL ',
#  'E 250 CDI AVANTGARDE ',
#  'VX MT PETROL ',
#  'MID MT',
#  'RXT Opt ',
#  '1.0L Turbo GDI SX MT ',
#  '1.0 CLIMBER OPT AMT ',
#  'VXI ',
#  'MAGNA O 1.2 ',
#  'VXI ',
#  '1.0 RXT Opt ',
#  'ERA 1.4 CRDI ',
#  '2.0 2WD AT ',
#  'ALPHA 1.5 MT VTVT SHVS ',
#  'ZXI SMART HYBRID ',
#  'SPORTZ 1.2 ',
#  'SPORTZ (O) 1.2 AT VTVT ',
# ...

# %%
len(model10)
# Out:
# 5575

# %%
transmission10=transmission+transmission1+transmission2+transmission3+transmission4+transmission5+transmission6+transmission7+transmission8+transmission9
transmission10
# Out:
# ['Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'MT',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Manual',
#  'Automatic',
#  'Manual',
#  'Manual',
#  'Manual',
#  'MT',
#  'Automatic',
# ...

# %%
len(transmission10)
# Out:
# 5575

# %%
driven10=driven+driven1+driven2+driven3+driven4+driven5+driven6+driven7+driven8+driven9
driven10
# Out:
# ['80631',
#  '12981',
#  '21784',
#  '20330',
#  '12849',
#  '11399',
#  '28289',
#  '44319',
#  '26866',
#  '32251',
#  '51495',
#  '46400',
#  '21490',
#  '2775',
#  '22505',
#  '22638',
#  '63433',
#  '45246',
#  '12511',
#  '6344',
#  '23315',
#  '16327',
#  '37580',
#  '9370',
#  '2213',
#  '19767',
#  '48915',
#  '90086',
#  '66782',
#  '42422',
#  '13223',
#  '7212',
#  '34566',
#  '42881',
#  '54517',
#  '11828',
#  '2406',
#  '29645',
#  '7760',
#  '26475',
#  '60774',
#  '5287',
#  '6962',
#  '29974',
#  '73937',
#  '4536',
#  '61780',
#  '30697',
#  '12855',
#  '45277',
#  '11358',
#  '6568',
#  '18191',
#  '82295',
#  '23733',
#  '3120',
#  '78203',
#  '32525',
#  '12267',
#  '17858',
#  '23874',
#  '62443',
#  '6910',
#  '31910',
#  '27693',
#  '76959',
#  '13278',
#  '19738',
#  '25238',
#  '22955',
#  '4210',
#  '12225',
#  '7661',
#  '49358',
#  '71745',
#  '45930',
#  '30375',
#  '51358',
#  '31760',
#  '26035',
#  '37503',
#  '34900',
#  '35669',
#  '19360',
# ...

# %%
len(driven10)
# Out:
# 5575

# %%
owner10=owner+owner1+owner2+owner3+owner4+owner5+owner6+owner7+owner8+owner9
owner10
# Out:
# ['1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '2nd',
#  '2nd',
#  '2nd',
#  '2nd',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '3rd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '1st',
#  '2nd',
#  '1st',
#  '1st',
#  '1st',
# ...

# %%
len(owner10)
# Out:
# 5575

# %%
fueltype10=fueltype+fueltype1+fueltype2+fueltype3+fueltype4+fueltype5+fueltype6+fueltype7+fueltype8+fueltype9
fueltype10
# Out:
# ['Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Petrol',
#  'Diesel',
#  'Diesel',
#  'Petrol',
# ...

# %%
len(fueltype10)
# Out:
# 5575

# %%
downpayment10=downpayment+downpayment1+downpayment2+downpayment3+downpayment4+downpayment5+downpayment6+downpayment7+downpayment8+downpayment9
downpayment10
# Out:
# ['21837',
#  '25699',
#  '31810',
#  '11674',
#  '5695',
#  '17433',
#  '36612',
#  '4542',
#  '7832',
#  '12466',
#  '9790',
#  '44934',
#  '18272',
#  '40883',
#  '7174',
#  '13745',
#  '6124',
#  '14781',
#  '7574',
#  '18278',
#  '11976',
#  '11371',
#  '5339',
#  '26996',
#  '26994',
#  '7748',
#  '5430',
#  '35097',
#  '6420',
#  '6015',
#  '13175',
#  '29156',
#  '9429',
#  '32379',
#  '14448',
#  '20596',
#  '8388',
#  '22033',
#  '12379',
#  '5239',
#  '6651',
#  '20247',
#  '11127',
#  '6813',
#  '28226',
#  '26349',
#  '19840',
#  '11629',
#  '13852',
#  '9543',
#  '9765',
#  '15807',
#  '24565',
#  '21450',
#  '13627',
#  '40096',
#  '19041',
#  '7574',
#  '39466',
#  '10397',
#  '6989',
#  '21630',
#  '23099',
#  '18296',
#  '12165',
#  '27572',
#  '19386',
#  '7892',
#  '9474',
#  '7928',
#  '8940',
#  '10866',
#  '21397',
#  '22794',
#  '28273',
#  '11887',
#  '8455',
#  '7105',
#  '20047',
#  '14935',
#  '31327',
#  '9327',
#  '12426',
#  '10853',
#  '15024',
# ...

# %%
len(downpayment10)
# Out:
# 5575

# %%
price10=price+price1+price2+price3+price4+price5+price6+price7+price8+price9
price10
# Out:
# ['981699',
#  '1155299',
#  '1429999',
#  '524799',
#  '255999',
#  '783699',
#  '1645899',
#  '204199',
#  '352099',
#  '560399',
#  '440099',
#  '2019999',
#  '821399',
#  '1837899',
#  '322499',
#  '617899',
#  '275299',
#  '664499',
#  '340499',
#  '821699',
#  '538399',
#  '511199',
#  '239999',
#  '1213599',
#  '1213499',
#  '348299',
#  '244099',
#  '1577799',
#  '288599',
#  '270399',
#  '592299',
#  '1310699',
#  '423899',
#  '1455599',
#  '649499',
#  '925899',
#  '377099',
#  '990499',
#  '556499',
#  '235499',
#  '298999',
#  '910199',
#  '500199',
#  '306299',
#  '1268899',
#  '1184499',
#  '891899',
#  '522799',
#  '622699',
#  '428999',
#  '438999',
#  '710599',
#  '1104299',
#  '964299',
#  '612599',
#  '1802499',
#  '855999',
#  '340499',
#  '1774199',
#  '467399',
#  '314199',
#  '972399',
#  '1038399',
#  '822499',
#  '546899',
#  '1239499',
#  '871499',
#  '354799',
#  '425899',
#  '356399',
#  '401899',
#  '488499',
#  '961899',
#  '1024699',
#  '1270999',
# ...

# %%
len(price10)
# Out:
# 5575

# %%
carname10=carnames+carnames1+carnames2+carnames3+carnames4+carnames5+carnames6+carnames7+carnames8+carnames9
carname10
# Out:
# [['Hyundai', 'Verna'],
#  ['KIA', 'SELTOS'],
#  ['KIA', 'SELTOS'],
#  ['Maruti', 'Baleno'],
#  ['Maruti', 'Alto', '800'],
#  ['Skoda', 'Rapid'],
#  ['Jaguar', 'XF'],
#  ['Hyundai', 'i10'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Maruti', 'Swift'],
#  ['Volkswagen', 'Polo'],
#  ['Jeep', 'Compass'],
#  ['Hyundai', 'VENUE'],
#  ['MG', 'HECTOR', 'PLUS'],
#  ['Renault', 'Kwid'],
#  ['Hyundai', 'Elite', 'i20'],
#  ['Nissan', 'Micra'],
#  ['Honda', 'City'],
#  ['Hyundai', 'i10'],
#  ['Renault', 'Kiger'],
#  ['Maruti', 'Baleno'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Maruti', 'Alto', 'K10'],
#  ['Maruti', 'Ciaz'],
#  ['Hyundai', 'VENUE'],
#  ['Renault', 'Kwid'],
#  ['Maruti', 'Wagon', 'R', '1.0'],
#  ['Toyota', 'Fortuner'],
#  ['Hyundai', 'i10'],
#  ['Hyundai', 'i20'],
#  ['Hyundai', 'Grand', 'i10'],
#  ['Honda', 'City'],
#  ['Honda', 'City'],
#  ['Mercedes', 'Benz', 'E', 'Class'],
#  ['Honda', 'City'],
#  ['Toyota', 'URBAN', 'CRUISER'],
#  ['Renault', 'Kwid'],
#  ['Hyundai', 'VENUE'],
# ...

# %%
len(carname10)
# Out:
# 5575

# %%
carfile=pd.DataFrame({'Brand':carname10,'Manufacturing_Year':year10,'Variant':model10,'Transmission':transmission10,'Owner':owner10,'Driven':driven10,'Fuel_Type':fueltype10,'Down_Payment':downpayment10,'Price':price10})
carfile
# Out:
#                        Brand Manufacturing_Year               Variant  \
# 0           [Hyundai, Verna]               2019      1.6 SX VTVT (O)
# 1              [KIA, SELTOS]               2020  HTK PLUS 1.5 PETROL
# 2              [KIA, SELTOS]               2020        HTX AT PETROL
# 3           [Maruti, Baleno]               2018        SIGMA 1.2 K12
# 4        [Maruti, Alto, 800]               2013                  LXI
# ...                      ...                ...                   ...
# 5570  [Maruti, Swift, Dzire]               2016              VDI ABS
# 5571   [Hyundai, Elite, i20]               2015       SPORTZ (O) 1.4
# 5572        [Maruti, Baleno]               2016        DELTA 1.2 K12
# 5573         [Maruti, Swift]               2012                  VDI
# 5574        [Toyota, Innova]               2014   2.5 GX 8 STR BS IV
#
#      Transmission Owner  Driven Fuel_Type Down_Payment    Price
# 0          Manual   1st   80631    Petrol        21837   981699
# ...

# %%
carfile.to_csv('car.csv')
