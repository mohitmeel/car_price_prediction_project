# %% [markdown]
# importing the libraries for the analysing of the dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import numpy as np

# %% [markdown]
# performing the EDA for better understanding of the dataset

# %%
df=pd.read_csv('Downloads/car1.csv')
df
# Out:
#       Unnamed: 0                 Brand  Manufacturing_Year  \
# 0              0        Hyundai, Verna                2019
# 1              1           KIA, SELTOS                2020
# 2              2           KIA, SELTOS                2020
# 3              3        Maruti, Baleno                2018
# 4              4     Maruti, Alto, 800                2013
# ...          ...                   ...                 ...
# 5570        5570  Maruti, Swift, Dzire                2016
# 5571        5571   Hyundai, Elite, i20                2015
# 5572        5572        Maruti, Baleno                2016
# 5573        5573         Maruti, Swift                2012
# 5574        5574        Toyota, Innova                2014
#
#                   Variant Transmission  Owner  Driven Fuel_Type  Down_Payment  \
# 0        1.6 SX VTVT (O)        Manual      1   80631    Petrol         21837
# 1          HTK PLUS 1.5         Manual      2   12981    Petrol         25699
# ...

# %%
df.head()
# Out:
#    Unnamed: 0              Brand  Manufacturing_Year           Variant  \
# 0           0     Hyundai, Verna                2019  1.6 SX VTVT (O)
# 1           1        KIA, SELTOS                2020    HTK PLUS 1.5
# 2           2        KIA, SELTOS                2020          HTX AT
# 3           3     Maruti, Baleno                2018    SIGMA 1.2 K12
# 4           4  Maruti, Alto, 800                2013              LXI
#
#   Transmission  Owner  Driven Fuel_Type  Down_Payment    Price
# 0       Manual      1   80631    Petrol         21837   981699
# 1       Manual      2   12981    Petrol         25699  1155299
# 2    Automatic      2   21784    Petrol         31810  1429999
# 3       Manual      1   20330    Petrol         11674   524799
# 4       Manual      2   12849    Petrol          5695   255999

# %%
df.tail()
# Out:
#       Unnamed: 0                 Brand  Manufacturing_Year  \
# 5570        5570  Maruti, Swift, Dzire                2016
# 5571        5571   Hyundai, Elite, i20                2015
# 5572        5572        Maruti, Baleno                2016
# 5573        5573         Maruti, Swift                2012
# 5574        5574        Toyota, Innova                2014
#
#                   Variant Transmission  Owner  Driven Fuel_Type  Down_Payment  \
# 5570             VDI ABS        Manual      2   58329    Diesel         10846
# 5571      SPORTZ (O) 1.4        Manual      1   63245    Diesel         12110
# 5572       DELTA 1.2 K12        Manual      1   87555    Petrol         10953
# 5573                 VDI        Manual      1  109227    Diesel          6769
# 5574  2.5 GX 8 STR BS IV        Manual      2  119551    Diesel         14948
#
#        Price
# 5570  487599
# 5571  544399
# 5572  492399
# 5573  304299
# 5574  671999

# %%
df.shape
# Out:
# (5575, 10)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Brand', 'Manufacturing_Year', 'Variant', 'Transmission',
#        'Owner', 'Driven', 'Fuel_Type', 'Down_Payment', 'Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Brand                 object
# Manufacturing_Year     int64
# Variant               object
# Transmission          object
# Owner                  int64
# Driven                 int64
# Fuel_Type             object
# Down_Payment           int64
# Price                  int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5575 entries, 0 to 5574
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          5575 non-null   int64
#  1   Brand               5575 non-null   object
#  2   Manufacturing_Year  5575 non-null   int64
#  3   Variant             5575 non-null   object
#  4   Transmission        5575 non-null   object
#  5   Owner               5575 non-null   int64
#  6   Driven              5575 non-null   int64
#  7   Fuel_Type           5575 non-null   object
#  8   Down_Payment        5575 non-null   int64
#  9   Price               5575 non-null   int64
# dtypes: int64(6), object(4)
# memory usage: 435.7+ KB

# %% [markdown]
# finding out that is there null values present in the columns of the dataset

# %%
df.isnull()
# Out:
#       Unnamed: 0  Brand  Manufacturing_Year  Variant  Transmission  Owner  \
# 0          False  False               False    False         False  False
# 1          False  False               False    False         False  False
# 2          False  False               False    False         False  False
# 3          False  False               False    False         False  False
# 4          False  False               False    False         False  False
# ...          ...    ...                 ...      ...           ...    ...
# 5570       False  False               False    False         False  False
# 5571       False  False               False    False         False  False
# 5572       False  False               False    False         False  False
# 5573       False  False               False    False         False  False
# 5574       False  False               False    False         False  False
#
#       Driven  Fuel_Type  Down_Payment  Price
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0            0
# Brand                 0
# Manufacturing_Year    0
# Variant               0
# Transmission          0
# Owner                 0
# Driven                0
# Fuel_Type             0
# Down_Payment          0
# Price                 0
# dtype: int64

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# the data type of columns is object is going to be converted in the numeric data type for maintaining the accuarcy by label encoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=le.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Unnamed: 0  Brand  Manufacturing_Year  Variant  Transmission  Owner  \
# 0              0     34                2019      125            12      1
# 1              1     41                2020      282            12      2
# 2              2     41                2020      283             4      2
# 3              3     57                2018      372            12      1
# 4              4     55                2013      299            12      2
# ...          ...    ...                 ...      ...           ...    ...
# 5570        5570     70                2016      439            12      2
# 5571        5571     25                2015      385            12      1
# 5572        5572     57                2016      227            12      1
# 5573        5573     69                2012      437            12      1
# 5574        5574    106                2014      152            12      2
#
#       Driven  Fuel_Type  Down_Payment    Price
# ...

# %% [markdown]
# now seeing the correlation betwwen the coulmns and the features with the target columns and also visualizing it with heatmap

# %%
dfcor=df.corr()
dfcor
# Out:
#                     Unnamed: 0     Brand  Manufacturing_Year   Variant  \
# Unnamed: 0            1.000000  0.003219            0.073244  0.006473
# Brand                 0.003219  1.000000           -0.006020  0.405495
# Manufacturing_Year    0.073244 -0.006020            1.000000 -0.014802
# Variant               0.006473  0.405495           -0.014802  1.000000
# Transmission          0.087638  0.020033           -0.148790  0.047824
# Owner                -0.005464 -0.071235           -0.147828 -0.029438
# Driven                0.009275  0.062184           -0.529102 -0.020953
# Fuel_Type             0.055964 -0.058526            0.298973 -0.003057
# Down_Payment         -0.100971 -0.087465            0.387437 -0.151034
# Price                -0.100970 -0.087464            0.387437 -0.151033
#
#                     Transmission     Owner    Driven  Fuel_Type  Down_Payment  \
# Unnamed: 0              0.087638 -0.005464  0.009275   0.055964     -0.100971
# ...

# %%
dfcor.Price
# Out:
# Unnamed: 0           -0.100970
# Brand                -0.087464
# Manufacturing_Year    0.387437
# Variant              -0.151033
# Transmission         -0.415563
# Owner                -0.040018
# Driven               -0.106212
# Fuel_Type            -0.181335
# Down_Payment          1.000000
# Price                 1.000000
# Name: Price, dtype: float64

# %%
plt.figure(figsize=(25,22))
sns.heatmap(dfcor,cmap='Blues',linewidths=2.5,linecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
# the statistical view of the dataset

# %%
df.describe()
# Out:
#         Unnamed: 0        Brand  Manufacturing_Year      Variant  \
# count  5575.000000  5575.000000         5575.000000  5575.000000
# mean   2787.000000    51.643229         2016.820987   324.786547
# std    1609.508206    25.768056            2.286422   153.348130
# min       0.000000     0.000000         2008.000000     0.000000
# 25%    1393.500000    28.000000         2015.000000   199.000000
# 50%    2787.000000    57.000000         2017.000000   347.000000
# 75%    4180.500000    69.000000         2019.000000   459.000000
# max    5574.000000   113.000000         2022.000000   581.000000
#
#        Transmission        Owner         Driven    Fuel_Type  Down_Payment  \
# count   5575.000000  5575.000000    5575.000000  5575.000000   5575.000000
# mean      10.822960     1.213453   45885.270314     0.635874  14653.153722
# std        2.906085     0.455401   30846.042874     0.481227   7619.613883
# min        0.000000     1.000000      71.000000     0.000000   4518.000000
# ...

# %% [markdown]
# now checking the outliers present in the dataset

# %%
df.plot(kind='box',subplots=True,layout=(8,10),figsize=(22,20))
# Out:
# Unnamed: 0               AxesSubplot(0.125,0.799681;0.065678x0.0803191)
# Brand                 AxesSubplot(0.203814,0.799681;0.065678x0.0803191)
# Manufacturing_Year    AxesSubplot(0.282627,0.799681;0.065678x0.0803191)
# Variant               AxesSubplot(0.361441,0.799681;0.065678x0.0803191)
# Transmission          AxesSubplot(0.440254,0.799681;0.065678x0.0803191)
# Owner                 AxesSubplot(0.519068,0.799681;0.065678x0.0803191)
# Driven                AxesSubplot(0.597881,0.799681;0.065678x0.0803191)
# Fuel_Type             AxesSubplot(0.676695,0.799681;0.065678x0.0803191)
# Down_Payment          AxesSubplot(0.755508,0.799681;0.065678x0.0803191)
# Price                 AxesSubplot(0.834322,0.799681;0.065678x0.0803191)
# dtype: object

# %% [markdown]
# removing the outliers in the dataset

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))
z
# Out:
#       Unnamed: 0     Brand  Manufacturing_Year   Variant  Transmission  \
# 0       1.731740  0.684755            0.953109  1.302947      0.405062
# 1       1.731119  0.413077            1.390513  0.279041      0.405062
# 2       1.730497  0.413077            1.390513  0.272519      2.348029
# 3       1.729876  0.207903            0.515705  0.307912      0.405062
# 4       1.729255  0.130280            1.671314  0.168172      0.405062
# ...          ...       ...                 ...       ...           ...
# 5570    1.729255  0.712449            0.359103  0.744865      0.405062
# 5571    1.729876  1.034056            0.796506  0.392694      0.405062
# 5572    1.730497  0.207903            0.359103  0.637734      0.405062
# 5573    1.731119  0.673637            2.108718  0.731822      0.405062
# 5574    1.731740  2.109653            1.233910  1.126861      0.405062
#
#          Owner    Driven  Fuel_Type  Down_Payment     Price
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([   7,   11,   11,   13,   13,   20,   47,   55,   55,   58,   58,
#          64,   81,   91,   91,  104,  104,  107,  118,  118,  122,  122,
#         130,  130,  140,  149,  161,  161,  162,  162,  169,  169,  260,
#         269,  297,  305,  323,  334,  334,  338,  341,  343,  343,  360,
#         360,  381,  390,  407,  407,  416,  416,  452,  452,  473,  495,
#         507,  592,  636,  645,  645,  647,  647,  685,  685,  702,  702,
#         707,  746,  746,  758,  782,  782,  785,  785,  835,  838,  838,
#         846,  846,  853,  853,  856,  856,  861,  885,  890,  890,  898,
#         898,  899,  899,  914,  914,  931,  938,  956,  965,  968,  985,
#         985,  987,  987, 1007, 1007, 1062, 1066, 1066, 1084, 1084, 1106,
#        1106, 1108, 1108, 1126, 1126, 1134, 1134, 1195, 1195, 1217, 1217,
#        1217, 1229, 1229, 1244, 1259, 1259, 1267, 1267, 1290, 1295, 1295,
#        1296, 1297, 1297, 1298, 1298, 1302, 1302, 1304, 1304, 1309, 1309,
# ...

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#       Unnamed: 0  Brand  Manufacturing_Year  Variant  Transmission  Owner  \
# 0              0     34                2019      125            12      1
# 1              1     41                2020      282            12      2
# 2              2     41                2020      283             4      2
# 3              3     57                2018      372            12      1
# 4              4     55                2013      299            12      2
# ...          ...    ...                 ...      ...           ...    ...
# 5570        5570     70                2016      439            12      2
# 5571        5571     25                2015      385            12      1
# 5572        5572     57                2016      227            12      1
# 5573        5573     69                2012      437            12      1
# 5574        5574    106                2014      152            12      2
#
#       Driven  Fuel_Type  Down_Payment    Price
# ...

# %%
df_new.shape
# Out:
# (5223, 10)

# %%
data_loss=((5575-5223)/5575)*100
data_loss
# Out:
# 6.313901345291479

# %% [markdown]
# as the data loss percentage after removing outliers present in the dataset is 6%
# which shows that such % of dataloss can be done and thus the accuracy of data can be maintained and it is also not becoming
# biased so the outliers present will be removed

# %%
df=df_new
df
# Out:
#       Unnamed: 0  Brand  Manufacturing_Year  Variant  Transmission  Owner  \
# 0              0     34                2019      125            12      1
# 1              1     41                2020      282            12      2
# 2              2     41                2020      283             4      2
# 3              3     57                2018      372            12      1
# 4              4     55                2013      299            12      2
# ...          ...    ...                 ...      ...           ...    ...
# 5570        5570     70                2016      439            12      2
# 5571        5571     25                2015      385            12      1
# 5572        5572     57                2016      227            12      1
# 5573        5573     69                2012      437            12      1
# 5574        5574    106                2014      152            12      2
#
#       Driven  Fuel_Type  Down_Payment    Price
# ...

# %% [markdown]
# now the checking the skewness in the columns

# %%
df.skew()
# Out:
# Unnamed: 0           -0.012197
# Brand                 0.047698
# Manufacturing_Year   -0.258165
# Variant              -0.362792
# Transmission         -2.114176
# Owner                 1.648116
# Driven                0.633201
# Fuel_Type            -0.613364
# Down_Payment          1.385168
# Price                 1.385169
# dtype: float64

# %%
df.plot(kind='kde',subplots=True,layout=(8,10),figsize=(35,32))
# Out:
# array([[<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>],
#        [<AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
#         <AxesSubplot:ylabel='Density'>, <AxesSubplot:ylabel='Density'>,
# ...

# %%
df.plot(kind='hist',subplots=True,layout=(8,10),figsize=(35,32))
# Out:
# array([[<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>],
#        [<AxesSubplot:ylabel='Frequency'>,
#         <AxesSubplot:ylabel='Frequency'>,
# ...

# %% [markdown]
# removing skewness by power transform

# %%
from sklearn.preprocessing import power_transform

# %%
df['Driven']=power_transform(df['Driven'].values.reshape(-1,1))

# %%
df.skew()
# Out:
# Unnamed: 0           -0.012197
# Brand                 0.047698
# Manufacturing_Year   -0.258165
# Variant              -0.362792
# Transmission         -2.114176
# Owner                 1.648116
# Driven               -0.080179
# Fuel_Type            -0.613364
# Down_Payment          1.385168
# Price                 1.385169
# dtype: float64

# %%
x=df.iloc[:,0:-1]
x
# Out:
#       Unnamed: 0  Brand  Manufacturing_Year  Variant  Transmission  Owner  \
# 0              0     34                2019      125            12      1
# 1              1     41                2020      282            12      2
# 2              2     41                2020      283             4      2
# 3              3     57                2018      372            12      1
# 4              4     55                2013      299            12      2
# ...          ...    ...                 ...      ...           ...    ...
# 5570        5570     70                2016      439            12      2
# 5571        5571     25                2015      385            12      1
# 5572        5572     57                2016      227            12      1
# 5573        5573     69                2012      437            12      1
# 5574        5574    106                2014      152            12      2
#
#         Driven  Fuel_Type  Down_Payment
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0        981699
# 1       1155299
# 2       1429999
# 3        524799
# 4        255999
#          ...
# 5570     487599
# 5571     544399
# 5572     492399
# 5573     304299
# 5574     671999
# Name: Price, Length: 5223, dtype: int64

# %%
x.shape
# Out:
# (5223, 9)

# %%
y.shape
# Out:
# (5223,)

# %% [markdown]
# scaling the data by using standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
x1=ss.fit_transform(x)
x1
# Out:
# array([[-1.73648511, -0.69125512,  0.96966929, ...,  1.24998942,
#          0.73935041,  1.29340752],
#        [-1.73586511, -0.41679048,  1.41750576, ..., -1.29066847,
#          0.73935041,  1.92372006],
#        [-1.73524512, -0.41679048,  1.41750576, ..., -0.7827325 ,
#          0.73935041,  2.9210893 ],
#        ...,
#        [ 1.71813143,  0.21055727, -0.37384013, ...,  1.42659395,
#          0.73935041, -0.48295753],
#        [ 1.71875142,  0.68106807, -2.16518603, ...,  1.93730557,
#         -1.35253864, -1.16582332],
#        [ 1.71937142,  2.13180973, -1.26951308, ...,  2.1622197 ,
#         -1.35253864,  0.1690618 ]])

# %%
x=pd.DataFrame(x1)
x
# Out:
#              0         1         2         3         4         5         6  \
# 0    -1.736485 -0.691255  0.969669 -1.306162  0.388407 -0.471818  1.249989
# 1    -1.735865 -0.416790  1.417506 -0.285373  0.388407  2.119461 -1.290668
# 2    -1.735245 -0.416790  1.417506 -0.278871 -2.543696  2.119461 -0.782732
# 3    -1.734625  0.210557  0.521833  0.299793  0.388407 -0.471818 -0.858143
# 4    -1.734005  0.132139 -1.717350 -0.174841  0.388407  2.119461 -1.299463
# ...        ...       ...       ...       ...       ...       ...       ...
# 5218  1.716891  0.720277 -0.373840  0.735416  0.388407  2.119461  0.620705
# 5219  1.717511 -1.044138 -0.821677  0.384317  0.388407 -0.471818  0.768787
# 5220  1.718131  0.210557 -0.373840 -0.642974  0.388407 -0.471818  1.426594
# 5221  1.718751  0.681068 -2.165186  0.722413  0.388407 -0.471818  1.937306
# 5222  1.719371  2.131810 -1.269513 -1.130612  0.388407  2.119461  2.162220
#
#              7         8
# 0     0.739350  1.293408
# ...

# %% [markdown]
# splitting the data for training and testing and importing the important libraries for calling models to make machine learn

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=368,test_size=.25)

# %%
x_train.shape
# Out:
# (3917, 9)

# %%
x_test.shape
# Out:
# (1306, 9)

# %%
y_test.shape
# Out:
# (1306,)

# %%
y_train.shape
# Out:
# (3917,)

# %% [markdown]
# finding out the best random state

# %%
maxsc=0
maxrs=0
for i in range(1,500):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=i)
    lm=LinearRegression()
    lm.fit(x_train,y_train)
    predlm=lm.predict(x_test)
    score=lm.score(x_train,y_train)
    if score>maxsc:
        maxsc=score
        maxrs=i
print(maxsc)
print(maxrs)
# Out:
# 0.999999997999786
# 368

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
predlm=lm.predict(x_test)
print('mean absolute error:',mean_absolute_error(y_test,predlm))
print('mean squared error:',mean_squared_error(y_test,predlm))
print(lm.score(x_train,y_train))
print(r2_score(y_test,predlm))
# Out:
# mean absolute error: 10.644522458240553
# mean squared error: 155.96222961822818
# 0.9999999978323659
# 0.9999999980161326

# %%
ls=Lasso(alpha=.0001)
ls.fit(x_train,y_train)
print(ls.score(x_train,y_train))
print(ls.coef_)
# Out:
# 0.9999999949134443
# [ 3.63839549e+00  2.48093537e+00 -1.66486642e+01  1.49475342e+00
#   7.94651593e+00 -1.35263112e+00 -1.07438613e-01  9.19241801e+00
#   2.75456569e+05]

# %%
plt.figure(figsize=(7,5))
plt.bar(x.columns,ls.coef_)
# Out:
# <BarContainer object of 9 artists>

# %%
rg=Ridge(alpha=.0001)
rg.fit(x_train,y_train)
print(rg.score(x_train,y_train))
print(rg.coef_)
# Out:
# 0.9999999978323648
# [ 2.69498236e-01 -1.69667417e-01 -1.82294169e-01  4.12070131e-02
#   1.82593011e-01 -8.41400475e-02 -1.49127732e-01 -5.39977596e-01
#   2.75444598e+05]

# %%
plt.figure(figsize=(7,5))
plt.bar(x.columns,rg.coef_)
# Out:
# <BarContainer object of 9 artists>

# %%
kernel_list=['linear','poly','rbf']
for i in kernel_list:
    svr=SVR(kernel=i)
    svr.fit(x_train,y_train)
    print(svr.score(x_train,y_train))
# Out:
# -0.03340539589139069
# -0.061083744887969305
# -0.06278206580206858

# %%
rfr=RandomForestRegressor()
rfr.fit(x_train,y_train)
predrfr=rfr.predict(x_test)
print('predicted car_price',predrfr)
print('actual car_price',y_test)
print('score',rfr.score(x_train,y_train))
# Out:
# predicted car_price [ 400151.    315810.   1617898.17 ...  799793.    990086.    484268.  ]
# actual car_price 827      399999
# 426      315799
# 376     1619599
# 2496     640899
# 1725     726199
#          ...
# 159     1306399
# 557      396999
# 5200     799899
# 628      989999
# 3741     484799
# Name: Price, Length: 1306, dtype: int64
# score 0.9999985839246306

# %%
lm=LinearRegression()
lm.fit(x_train,y_train)
predlm=lm.predict(x_test)
print('predicted car_price',predlm)
print('actual car_price',y_test)
print('score',lm.score(x_train,y_train))
# Out:
# predicted car_price [ 400009.61388279  315808.61058691 1619594.38931529 ...  799885.72787182
#   989999.72905962  484795.02683828]
# actual car_price 827      399999
# 426      315799
# 376     1619599
# 2496     640899
# 1725     726199
#          ...
# 159     1306399
# 557      396999
# 5200     799899
# 628      989999
# 3741     484799
# Name: Price, Length: 1306, dtype: int64
# score 0.9999999978323659

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predrfr,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('actual car_price',fontsize=14)
plt.ylabel('predicted car_price',fontsize=14)
plt.title('random forest regressor',fontsize=18)
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=predlm,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('actual car_price',fontsize=14)
plt.ylabel('predicted car_price',fontsize=14)
plt.title('linear regression',fontsize=18)
plt.show()

# %%
carprice=pd.DataFrame({'predicted car_price':predrfr,'actual car_price':y_test})
carprice
# Out:
#       predicted car_price  actual car_price
# 827             400151.00            399999
# 426             315810.00            315799
# 376            1617898.17           1619599
# 2496            640662.00            640899
# 1725            726237.00            726199
# ...                   ...               ...
# 159            1308536.00           1306399
# 557             396996.00            396999
# 5200            799793.00            799899
# 628             990086.00            989999
# 3741            484268.00            484799
#
# [1306 rows x 2 columns]

# %%
pd.set_option('display.max_rows',None)
carprice
# Out:
#       predicted car_price  actual car_price
# 827             400151.00            399999
# 426             315810.00            315799
# 376            1617898.17           1619599
# 2496            640662.00            640899
# 1725            726237.00            726199
# 2152            339089.00            339099
# 3280            483259.00            483199
# 4092            479933.00            480099
# 1839            631325.00            631299
# 134            1562543.00           1561899
# 4646            352427.20            352399
# 3203            834317.00            834399
# 4936            440136.00            440099
# 2426            771102.00            771299
# 253             556686.00            556699
# 4282            320438.00            320399
# 2759            576565.00            576799
# 4263           1426023.00           1425399
# 2346           1370650.00           1369799
# 3193            862652.00            862599
# ...

# %%
import pickle
filename='carprice.pkl'
pickle.dump(rfr,open(filename,'wb'))

# %% [markdown]
# the best model is linear regression and random forest regressor, both score is 99% but there is very less difference between both. at last the best model is linear regression.

# %% [markdown]
# completed
